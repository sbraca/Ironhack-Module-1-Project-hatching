# %%
# !pip install requests
# Out:
# Collecting requests
#   Downloading https://files.pythonhosted.org/packages/51/bd/23c926cd341ea6b7dd0b2a00aba99ae0f828be89d72b2190f27c11d4b7fb/requests-2.22.0-py2.py3-none-any.whl (57kB)
#      |████████████████████████████████| 61kB 3.3MB/s eta 0:00:01
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading https://files.pythonhosted.org/packages/b4/40/a9837291310ee1ccc242ceb6ebfd9eb21539649f193a7c8c86ba15b98539/urllib3-1.25.7-py2.py3-none-any.whl (125kB)
#      |████████████████████████████████| 133kB 4.0MB/s eta 0:00:01
# Collecting chardet<3.1.0,>=3.0.2
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
#      |████████████████████████████████| 143kB 4.0MB/s eta 0:00:01     |█████████▉                      | 40kB 5.1MB/s eta 0:00:01
# Collecting idna<2.9,>=2.5
#   Downloading https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 6.4MB/s eta 0:00:011
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Stefania/opt/anaconda3/envs/data_env/lib/python3.7/site-packages (from requests) (2019.9.11)
# Installing collected packages: urllib3, chardet, idna, requests
# Successfully installed chardet-3.0.4 idna-2.8 requests-2.22.0 urllib3-1.25.7

# %%
import json
import requests

# %%
response = requests.get('https://jsonplaceholder.typicode.com/todos')
results = response.json()
results[0:5]
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False}]

# %%
import pandas as pd

data = pd.DataFrame(results)
data.head(10)
# Out:
#    userId  id                                              title  completed
# 0       1   1                                 delectus aut autem      False
# 1       1   2                 quis ut nam facilis et officia qui      False
# 2       1   3                                fugiat veniam minus      False
# 3       1   4                                   et porro tempora       True
# 4       1   5  laboriosam mollitia et enim quasi adipisci qui...      False
# 5       1   6  qui ullam ratione quibusdam voluptatem quia omnis      False
# 6       1   7                  illo expedita consequatur quia in      False
# 7       1   8                       quo adipisci enim quam ut ab       True
# 8       1   9                        molestiae perspiciatis ipsa      False
# 9       1  10       illo est ratione doloremque quia maiores aut       True

# %%
response = requests.get('https://api.github.com/events')

data = pd.DataFrame(response.json())
data.head(10)
# Out:
#             id                           type  \
# 0  11196980039                      PushEvent
# 1  11196980041                      PushEvent
# 2  11196980033                      PushEvent
# 3  11196980032                      PushEvent
# 4  11196980031                    IssuesEvent
# 5  11196980028  PullRequestReviewCommentEvent
# 6  11196980020                      PushEvent
# 7  11196980021                      PushEvent
# 8  11196980012                      PushEvent
# 9  11196980014                      PushEvent
#
#                                                actor  \
# 0  {'id': 44589228, 'login': 'RisingFisan', 'disp...
# 1  {'id': 57106225, 'login': 'tchiggins', 'displa...
# 2  {'id': 58256670, 'login': 'xiannvmiao', 'displ...
# 3  {'id': 54845926, 'login': 'MD-Mood', 'display_...
# 4  {'id': 717550, 'login': 'brijeshb42', 'display...
# 5  {'id': 175315, 'login': 'dnadales', 'display_l...
# 6  {'id': 9592259, 'login': 'dagheyman', 'display...
# 7  {'id': 58833107, 'login': 'ffbns289', 'display...
# 8  {'id': 58833107, 'login': 'ffbns289', 'display...
# 9  {'id': 373485, 'login': 'ulyssessouza', 'displ...
#
#                                                 repo  \
# 0  {'id': 231575297, 'name': 'RisingFisan/Rusteze...
# 1  {'id': 231224037, 'name': 'tchiggins/WhatPetAS...
# 2  {'id': 229511718, 'name': 'xiannvmiao/imgs', '...
# 3  {'id': 230644646, 'name': 'MD-Mood/Mytest', 'u...
# 4  {'id': 145301455, 'name': 'brijeshb42/monaco-v...
# 5  {'id': 150113380, 'name': 'input-output-hk/car...
# 6  {'id': 16949032, 'name': 'Yubico/yubioath-desk...
# 7  {'id': 227725053, 'name': 'ffbns289/ntdtv', 'u...
# 8  {'id': 227724995, 'name': 'ffbns289/djy', 'url...
# 9  {'id': 157380448, 'name': 'ulyssessouza/app', ...
#
#                                              payload  public  \
# 0  {'push_id': 4457288702, 'size': 1, 'distinct_s...    True
# 1  {'push_id': 4457288701, 'size': 1, 'distinct_s...    True
# 2  {'push_id': 4457288690, 'size': 1, 'distinct_s...    True
# 3  {'push_id': 4457288693, 'size': 1, 'distinct_s...    True
# 4  {'action': 'closed', 'issue': {'url': 'https:/...    True
# 5  {'action': 'created', 'comment': {'url': 'http...    True
# 6  {'push_id': 4457288685, 'size': 3, 'distinct_s...    True
# 7  {'push_id': 4457288679, 'size': 1, 'distinct_s...    True
# 8  {'push_id': 4457288673, 'size': 1, 'distinct_s...    True
# 9  {'push_id': 4457288686, 'size': 1, 'distinct_s...    True
#
#              created_at                                                org
# 0  2020-01-03T11:47:22Z                                                NaN
# 1  2020-01-03T11:47:22Z                                                NaN
# 2  2020-01-03T11:47:22Z                                                NaN
# 3  2020-01-03T11:47:22Z                                                NaN
# 4  2020-01-03T11:47:22Z                                                NaN
# 5  2020-01-03T11:47:21Z  {'id': 12909177, 'login': 'input-output-hk', '...
# 6  2020-01-03T11:47:22Z  {'id': 531825, 'login': 'Yubico', 'gravatar_id...
# 7  2020-01-03T11:47:22Z                                                NaN
# 8  2020-01-03T11:47:22Z                                                NaN
# 9  2020-01-03T11:47:22Z                                                NaN

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
nested_columns = ['actor', 'org', 'payload', 'repo']

# %%
flat = flatten(data, nested_columns)
flat.head(10)
# Out:
#             id                           type  public            created_at  \
# 0  11196980039                      PushEvent    True  2020-01-03T11:47:22Z
# 1  11196980041                      PushEvent    True  2020-01-03T11:47:22Z
# 2  11196980033                      PushEvent    True  2020-01-03T11:47:22Z
# 3  11196980032                      PushEvent    True  2020-01-03T11:47:22Z
# 4  11196980031                    IssuesEvent    True  2020-01-03T11:47:22Z
# 5  11196980028  PullRequestReviewCommentEvent    True  2020-01-03T11:47:21Z
# 6  11196980020                      PushEvent    True  2020-01-03T11:47:22Z
# 7  11196980021                      PushEvent    True  2020-01-03T11:47:22Z
# 8  11196980012                      PushEvent    True  2020-01-03T11:47:22Z
# 9  11196980014                      PushEvent    True  2020-01-03T11:47:22Z
#
#    actor_id   actor_login actor_display_login actor_gravatar_id  \
# 0  44589228   RisingFisan         RisingFisan
# 1  57106225     tchiggins           tchiggins
# 2  58256670    xiannvmiao          xiannvmiao
# 3  54845926       MD-Mood             MD-Mood
# 4    717550    brijeshb42          brijeshb42
# 5    175315      dnadales            dnadales
# 6   9592259     dagheyman           dagheyman
# 7  58833107      ffbns289            ffbns289
# 8  58833107      ffbns289            ffbns289
# 9    373485  ulyssessouza        ulyssessouza
#
#                                    actor_url  \
# 0   https://api.github.com/users/RisingFisan
# 1     https://api.github.com/users/tchiggins
# 2    https://api.github.com/users/xiannvmiao
# 3       https://api.github.com/users/MD-Mood
# 4    https://api.github.com/users/brijeshb42
# 5      https://api.github.com/users/dnadales
# 6     https://api.github.com/users/dagheyman
# 7      https://api.github.com/users/ffbns289
# 8      https://api.github.com/users/ffbns289
# 9  https://api.github.com/users/ulyssessouza
#
#                                     actor_avatar_url  ...  \
# 0  https://avatars.githubusercontent.com/u/44589228?  ...
# 1  https://avatars.githubusercontent.com/u/57106225?  ...
# 2  https://avatars.githubusercontent.com/u/58256670?  ...
# 3  https://avatars.githubusercontent.com/u/54845926?  ...
# 4    https://avatars.githubusercontent.com/u/717550?  ...
# 5    https://avatars.githubusercontent.com/u/175315?  ...
# 6   https://avatars.githubusercontent.com/u/9592259?  ...
# 7  https://avatars.githubusercontent.com/u/58833107?  ...
# 8  https://avatars.githubusercontent.com/u/58833107?  ...
# 9    https://avatars.githubusercontent.com/u/373485?  ...
#
#                                      payload_comment  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  {'url': 'https://api.github.com/repos/input-ou...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                 payload_pull_request payload_number  \
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
# 5  {'url': 'https://api.github.com/repos/input-ou...            NaN
# 6                                                NaN            NaN
# 7                                                NaN            NaN
# 8                                                NaN            NaN
# 9                                                NaN            NaN
#
#   payload_ref_type payload_master_branch payload_description  \
# 0              NaN                   NaN                 NaN
# 1              NaN                   NaN                 NaN
# 2              NaN                   NaN                 NaN
# 3              NaN                   NaN                 NaN
# 4              NaN                   NaN                 NaN
# 5              NaN                   NaN                 NaN
# 6              NaN                   NaN                 NaN
# 7              NaN                   NaN                 NaN
# 8              NaN                   NaN                 NaN
# 9              NaN                   NaN                 NaN
#
#   payload_pusher_type    repo_id                             repo_name  \
# 0                 NaN  231575297                   RisingFisan/Rusteze
# 1                 NaN  231224037                  tchiggins/WhatPetASP
# 2                 NaN  229511718                       xiannvmiao/imgs
# 3                 NaN  230644646                        MD-Mood/Mytest
# 4                 NaN  145301455                 brijeshb42/monaco-vim
# 5                 NaN  150113380  input-output-hk/cardano-ledger-specs
# 6                 NaN   16949032               Yubico/yubioath-desktop
# 7                 NaN  227725053                        ffbns289/ntdtv
# 8                 NaN  227724995                          ffbns289/djy
# 9                 NaN  157380448                      ulyssessouza/app
#
#                                             repo_url
# 0   https://api.github.com/repos/RisingFisan/Rusteze
# 1  https://api.github.com/repos/tchiggins/WhatPetASP
# 2       https://api.github.com/repos/xiannvmiao/imgs
# 3        https://api.github.com/repos/MD-Mood/Mytest
# 4  https://api.github.com/repos/brijeshb42/monaco...
# 5  https://api.github.com/repos/input-output-hk/c...
# 6  https://api.github.com/repos/Yubico/yubioath-d...
# 7        https://api.github.com/repos/ffbns289/ntdtv
# 8          https://api.github.com/repos/ffbns289/djy
# 9      https://api.github.com/repos/ulyssessouza/app
#
# [10 rows x 34 columns]

# %%
from pandas.io.json import json_normalize

# %%
results = response.json()
flattened_data = json_normalize(results)

# %%
flattened_data
# Out:
#              id                           type  public            created_at  \
# 0   11196980039                      PushEvent    True  2020-01-03T11:47:22Z
# 1   11196980041                      PushEvent    True  2020-01-03T11:47:22Z
# 2   11196980033                      PushEvent    True  2020-01-03T11:47:22Z
# 3   11196980032                      PushEvent    True  2020-01-03T11:47:22Z
# 4   11196980031                    IssuesEvent    True  2020-01-03T11:47:22Z
# 5   11196980028  PullRequestReviewCommentEvent    True  2020-01-03T11:47:21Z
# 6   11196980020                      PushEvent    True  2020-01-03T11:47:22Z
# 7   11196980021                      PushEvent    True  2020-01-03T11:47:22Z
# 8   11196980012                      PushEvent    True  2020-01-03T11:47:22Z
# 9   11196980014                      PushEvent    True  2020-01-03T11:47:22Z
# 10  11196980018                    IssuesEvent    True  2020-01-03T11:47:22Z
# 11  11196980003                      PushEvent    True  2020-01-03T11:47:22Z
# 12  11196980007  PullRequestReviewCommentEvent    True  2020-01-03T11:47:21Z
# 13  11196980000  PullRequestReviewCommentEvent    True  2020-01-03T11:47:21Z
# 14  11196979977                      PushEvent    True  2020-01-03T11:47:22Z
# 15  11196979978                      PushEvent    True  2020-01-03T11:47:22Z
# 16  11196979988                      PushEvent    True  2020-01-03T11:47:22Z
# 17  11196979966                      PushEvent    True  2020-01-03T11:47:22Z
# 18  11196979976                      PushEvent    True  2020-01-03T11:47:22Z
# 19  11196979971                      PushEvent    True  2020-01-03T11:47:22Z
# 20  11196979967               PullRequestEvent    True  2020-01-03T11:47:22Z
# 21  11196979970                    CreateEvent    True  2020-01-03T11:47:22Z
# 22  11196979956               PullRequestEvent    True  2020-01-03T11:47:21Z
# 23  11196979942                      PushEvent    True  2020-01-03T11:47:21Z
# 24  11196979939                      PushEvent    True  2020-01-03T11:47:21Z
# 25  11196979938                    DeleteEvent    True  2020-01-03T11:47:21Z
# 26  11196979933                      PushEvent    True  2020-01-03T11:47:21Z
# 27  11196979932                    CreateEvent    True  2020-01-03T11:47:21Z
# 28  11196979930                      PushEvent    True  2020-01-03T11:47:21Z
# 29  11196979928                    DeleteEvent    True  2020-01-03T11:47:21Z
#
#     actor.id              actor.login   actor.display_login actor.gravatar_id  \
# 0   44589228              RisingFisan           RisingFisan
# 1   57106225                tchiggins             tchiggins
# 2   58256670               xiannvmiao            xiannvmiao
# 3   54845926                  MD-Mood               MD-Mood
# 4     717550               brijeshb42            brijeshb42
# 5     175315                 dnadales              dnadales
# 6    9592259                dagheyman             dagheyman
# 7   58833107                 ffbns289              ffbns289
# 8   58833107                 ffbns289              ffbns289
# 9     373485             ulyssessouza          ulyssessouza
# 10    703790              mathiasrabe           mathiasrabe
# 11   7532571               defcon8808            defcon8808
# 12  18637116            nowakprojects         nowakprojects
# 13   7549123            andrei-cosmin         andrei-cosmin
# 14  19927972                 SaschaSZ              SaschaSZ
# 15  53973962                   gcnyin                gcnyin
# 16   3080733                bigmarvin             bigmarvin
# 17   9945286                avilavate             avilavate
# 18  46819243              igorpieniek           igorpieniek
# 19  59052678           MaksimR-AVISPL        MaksimR-AVISPL
# 20  55845206            CHOI-SEUNGJUN         CHOI-SEUNGJUN
# 21   1314201                 ahairshi              ahairshi
# 22  12989489                 jdorigao              jdorigao
# 23  33154059                 DQYXACML              DQYXACML
# 24    741710              jonstoneman           jonstoneman
# 25  27856297  dependabot-preview[bot]    dependabot-preview
# 26  57821319               y939026701            y939026701
# 27  47148648     svc-software-factory  svc-software-factory
# 28  44917367           khoanguyen1412        khoanguyen1412
# 29   7983669               servibilis            servibilis
#
#                                             actor.url  \
# 0            https://api.github.com/users/RisingFisan
# 1              https://api.github.com/users/tchiggins
# 2             https://api.github.com/users/xiannvmiao
# 3                https://api.github.com/users/MD-Mood
# 4             https://api.github.com/users/brijeshb42
# 5               https://api.github.com/users/dnadales
# 6              https://api.github.com/users/dagheyman
# 7               https://api.github.com/users/ffbns289
# 8               https://api.github.com/users/ffbns289
# 9           https://api.github.com/users/ulyssessouza
# 10           https://api.github.com/users/mathiasrabe
# 11            https://api.github.com/users/defcon8808
# 12         https://api.github.com/users/nowakprojects
# 13         https://api.github.com/users/andrei-cosmin
# 14              https://api.github.com/users/SaschaSZ
# 15                https://api.github.com/users/gcnyin
# 16             https://api.github.com/users/bigmarvin
# 17             https://api.github.com/users/avilavate
# 18           https://api.github.com/users/igorpieniek
# 19        https://api.github.com/users/MaksimR-AVISPL
# 20         https://api.github.com/users/CHOI-SEUNGJUN
# 21              https://api.github.com/users/ahairshi
# 22              https://api.github.com/users/jdorigao
# 23              https://api.github.com/users/DQYXACML
# 24           https://api.github.com/users/jonstoneman
# 25  https://api.github.com/users/dependabot-previe...
# 26            https://api.github.com/users/y939026701
# 27  https://api.github.com/users/svc-software-factory
# 28        https://api.github.com/users/khoanguyen1412
# 29            https://api.github.com/users/servibilis
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/44589228?  ...
# 1   https://avatars.githubusercontent.com/u/57106225?  ...
# 2   https://avatars.githubusercontent.com/u/58256670?  ...
# 3   https://avatars.githubusercontent.com/u/54845926?  ...
# 4     https://avatars.githubusercontent.com/u/717550?  ...
# 5     https://avatars.githubusercontent.com/u/175315?  ...
# 6    https://avatars.githubusercontent.com/u/9592259?  ...
# 7   https://avatars.githubusercontent.com/u/58833107?  ...
# 8   https://avatars.githubusercontent.com/u/58833107?  ...
# 9     https://avatars.githubusercontent.com/u/373485?  ...
# 10    https://avatars.githubusercontent.com/u/703790?  ...
# 11   https://avatars.githubusercontent.com/u/7532571?  ...
# 12  https://avatars.githubusercontent.com/u/18637116?  ...
# 13   https://avatars.githubusercontent.com/u/7549123?  ...
# 14  https://avatars.githubusercontent.com/u/19927972?  ...
# 15  https://avatars.githubusercontent.com/u/53973962?  ...
# 16   https://avatars.githubusercontent.com/u/3080733?  ...
# 17   https://avatars.githubusercontent.com/u/9945286?  ...
# 18  https://avatars.githubusercontent.com/u/46819243?  ...
# 19  https://avatars.githubusercontent.com/u/59052678?  ...
# 20  https://avatars.githubusercontent.com/u/55845206?  ...
# 21   https://avatars.githubusercontent.com/u/1314201?  ...
# 22  https://avatars.githubusercontent.com/u/12989489?  ...
# 23  https://avatars.githubusercontent.com/u/33154059?  ...
# 24    https://avatars.githubusercontent.com/u/741710?  ...
# 25  https://avatars.githubusercontent.com/u/27856297?  ...
# 26  https://avatars.githubusercontent.com/u/57821319?  ...
# 27  https://avatars.githubusercontent.com/u/47148648?  ...
# 28  https://avatars.githubusercontent.com/u/44917367?  ...
# 29   https://avatars.githubusercontent.com/u/7983669?  ...
#
#          payload.pull_request.merged_by.following_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  https://api.github.com/users/jdorigao/followin...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#              payload.pull_request.merged_by.gists_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  https://api.github.com/users/jdorigao/gists{/g...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#            payload.pull_request.merged_by.starred_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  https://api.github.com/users/jdorigao/starred{...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#      payload.pull_request.merged_by.subscriptions_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  https://api.github.com/users/jdorigao/subscrip...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#     payload.pull_request.merged_by.organizations_url  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22        https://api.github.com/users/jdorigao/orgs
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
#
#        payload.pull_request.merged_by.repos_url  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22  https://api.github.com/users/jdorigao/repos
# 23                                          NaN
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
#
#             payload.pull_request.merged_by.events_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  https://api.github.com/users/jdorigao/events{/...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#    payload.pull_request.merged_by.received_events_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  https://api.github.com/users/jdorigao/received...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#    payload.pull_request.merged_by.type  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9                                  NaN
# 10                                 NaN
# 11                                 NaN
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
# 15                                 NaN
# 16                                 NaN
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                                 NaN
# 21                                 NaN
# 22                                User
# 23                                 NaN
# 24                                 NaN
# 25                                 NaN
# 26                                 NaN
# 27                                 NaN
# 28                                 NaN
# 29                                 NaN
#
#    payload.pull_request.merged_by.site_admin
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21                                       NaN
# 22                                     False
# 23                                       NaN
# 24                                       NaN
# 25                                       NaN
# 26                                       NaN
# 27                                       NaN
# 28                                       NaN
# 29                                       NaN
#
# [30 rows x 462 columns]
