# %%
import pandas as pd

# %%
final_df = pd.read_csv('forbes2.csv')

# %%
top10_df = pd.read_csv('top10_df.csv')

# %%
final_df.head()
# Out:
#      ID  Position       Worth First Name   Last Name  Age     Gender_cat  \
# 0  5227         1  112.0 BUSD       Jeff       Bezos   54  Not Available
# 1  2642         2   90.0 BUSD       Bill       Gates   62           Male
# 2  5422         3   84.0 BUSD     Warren     Buffett   87           Male
# 3  8183         4   72.0 BUSD    Bernard     Arnault   69           Male
# 4  5642         5   71.0 BUSD       Mark  Zuckerberg   33           Male
#
#                                             Source        Country  \
# 0                           Technology  ==> Amazon  United States
# 1                        Technology  ==> Microsoft           None
# 2  Finance and Investments  ==> Berkshire Hathaway           None
# 3                       Fashion & Retail  ==> LVMH         France
# 4                         Technology  ==> Facebook            USA
#
#                                                Image
# 0  https://specials-images.forbesimg.com/imageser...
# 1  https://specials-images.forbesimg.com/imageser...
# 2  https://specials-images.forbesimg.com/imageser...
# 3  https://specials-images.forbesimg.com/imageser...
# 4  https://specials-images.forbesimg.com/imageser...

# %%
top10_df.head()
# Out:
#    No.             Name Net worth (USD)  Age     Nationality  \
# 0    1       Jeff Bezos   $131 billion    55   United States
# 1    2       Bill Gates  $96.5 billion    63   United States
# 2    3   Warren Buffett  $82.5 billion    88   United States
# 3    4  Bernard Arnault    $76 billion    70          France
# 4    5      Carlos Slim    $64 billion    79          Mexico
#
#           Source(s) of wealth
# 0                      Amazon
# 1                   Microsoft
# 2          Berkshire Hathaway
# 3                        LVMH
# 4  América Móvil, Grupo Carso

# %%
top10_df.rename(columns={"No.": "Position"})
# Out:
#    Position               Name Net worth (USD)  Age     Nationality  \
# 0         1         Jeff Bezos   $131 billion    55   United States
# 1         2         Bill Gates  $96.5 billion    63   United States
# 2         3     Warren Buffett  $82.5 billion    88   United States
# 3         4    Bernard Arnault    $76 billion    70          France
# 4         5        Carlos Slim    $64 billion    79          Mexico
# 5         6     Amancio Ortega  $62.7 billion    82           Spain
# 6         7      Larry Ellison  $62.5 billion    74   United States
# 7         8    Mark Zuckerberg  $62.3 billion    34   United States
# 8         9  Michael Bloomberg  $55.5 billion    77   United States
# 9        10         Larry Page  $50.8 billion    45   United States
#
#           Source(s) of wealth
# 0                      Amazon
# 1                   Microsoft
# 2          Berkshire Hathaway
# 3                        LVMH
# 4  América Móvil, Grupo Carso
# 5               Inditex, Zara
# 6          Oracle Corporation
# 7                    Facebook
# 8              Bloomberg L.P.
# 9               Alphabet Inc.

# %%
top10_df.drop(columns=['Name', 'Net worth (USD)','Age', 'Source(s) of wealth'], inplace=True)

# %%
top10_df.head(10)
# Out:
#    No.     Nationality
# 0    1   United States
# 1    2   United States
# 2    3   United States
# 3    4          France
# 4    5          Mexico
# 5    6           Spain
# 6    7   United States
# 7    8   United States
# 8    9   United States
# 9   10   United States

# %%
full_df = pd.read_csv('forbes_2018.csv')

# %%
full_df.head()
# Out:
#    position                         name      lastName   age         country  \
# 0       NaN  Anant Asavabhokhin & family  Asavabhokhin  67.0        Thailand
# 1       NaN               Arash Ferdowsi      Ferdowsi  32.0   United States
# 2       NaN     Banthoon Lamsam & family        Lamsam  65.0        Thailand
# 3       NaN       Bill Adderley & family      Adderley  70.0  United Kingdom
# 4       NaN            Boris Zingarevich   Zingarevich  58.0          Russia
#
#   gender                 wealthSource                 industry  worth  \
# 0      M                  real estate              Real Estate    NaN
# 1      M          online file storage               Technology    NaN
# 2      M                      banking  Finance and Investments    NaN
# 3      M             home furnishings         Fashion & Retail    NaN
# 4      M  pulp and paper, diversified              Diversified    NaN
#
#    worthChange  realTimeWorth  realTimePosition  \
# 0       -0.001            NaN              1613
# 1        0.000            NaN              1734
# 2        0.001            NaN              1952
# 3        0.000            NaN              1956
# 4        0.000            NaN              2103
#
#                                                image
# 0  https://specials-images.forbesimg.com/imageser...
# 1  https://specials-images.forbesimg.com/imageser...
# 2  https://specials-images.forbesimg.com/imageser...
# 3  https://specials-images.forbesimg.com/imageser...
# 4  https://specials-images.forbesimg.com/imageser...

# %%
full_df['country'].value_counts()
# Out:
# United States    596
# China            380
# Germany          125
# India            120
# Russia           104
#                 ...
# Nepal              1
# Swaziland          1
# Portugal           1
# Iceland            1
# Angola             1
# Name: country, Length: 72, dtype: int64

# %%
full_df.country.unique()
# Out:
# array(['Thailand', 'United States', 'United Kingdom', 'Russia', 'Sweden',
#        'Taiwan', 'Germany', 'Netherlands', 'China', 'France', 'Japan',
#        'Indonesia', 'Ireland', 'South Korea', 'Canada', 'Philippines',
#        'India', 'Egypt', 'Spain', 'Mexico', 'Hong Kong', 'Brazil',
#        'Italy', 'Austria', 'Australia', 'Chile', 'Czech Republic',
#        'Malaysia', 'Nigeria', 'Colombia', 'Singapore', 'New Zealand',
#        'Israel', 'Switzerland', 'South Africa', 'Denmark', 'Cyprus',
#        'Norway', 'Belgium', 'United Arab Emirates', 'Ukraine', 'Portugal',
#        'Turkey', 'Georgia', 'Venezuela', 'Swaziland', 'Vietnam',
#        'Finland', 'Algeria', 'Oman', 'Liechtenstein', 'Poland', 'Peru',
#        'Kazakhstan', 'Greece', 'Argentina', 'Lebanon', 'Angola',
#        'Guernsey', 'Morocco', 'Monaco', 'Iceland', 'Qatar',
#        'St. Kitts and Nevis', 'Nepal', 'Tanzania', 'Kuwait', 'Macau',
#        'Zimbabwe', 'Slovakia', 'Romania', 'Hungary'], dtype=object)

# %%
full_df.tail(15)
# Out:
#       position                    name  lastName   age        country gender  \
# 2245    2194.0          Surin Upatkoon  Upatkoon  69.0       Thailand      M
# 2246    2195.0           Alexander Vik       Vik  63.0         Norway      M
# 2247    2196.0  Peter-Alexander Wacker    Wacker  66.0        Germany      M
# 2259  https://specials-images.forbesimg.com/imageser...

# %%
full_df.sort_values(by=['position'])
# Out:
#     position                      name    lastName   age        country  \
# 52       1.0                Jeff Bezos       Bezos  54.0  United States
# 53       2.0                Bill Gates       Gates  62.0  United States
# 54       3.0            Warren Buffett     Buffett  87.0  United States
# 55       4.0           Bernard Arnault     Arnault  69.0         France
# 56       5.0           Mark Zuckerberg  Zuckerberg  34.0  United States
# ..       ...                       ...         ...   ...            ...
# 47       NaN  Supaluck Umpujh & family      Umpujh  63.0       Thailand
# 48       NaN               Thomas Duff        Duff  61.0  United States
# 49       NaN           Zakhar Smushkin    Smushkin  56.0         Russia
# 50       NaN  Zhang Zhongneng & family       Zhang  55.0          China
# 51       NaN                 Zhu Yicai         Zhu  54.0          China
#
#    gender                 wealthSource                 industry     worth  \
# 52      M                       Amazon               Technology  112000.0
# 53      M                    Microsoft               Technology   90000.0
# 54      M           Berkshire Hathaway  Finance and Investments   84000.0
# 55      M                         LVMH         Fashion & Retail   72000.0
# 56      M                     Facebook               Technology   71000.0
# ..    ...                          ...                      ...       ...
# 47      F                       retail         Fashion & Retail       NaN
# 48      M           tires, diversified         Fashion & Retail       NaN
# 49      M  pulp and paper, diversified              Diversified       NaN
# 50      M                     aluminum            Manufacturing       NaN
# 51      M     meat products, retailing              Diversified       NaN
#
#     worthChange  realTimeWorth  realTimePosition  \
# 52        0.000            NaN                 1
# 53       -0.001            NaN                 2
# 54       -0.002            NaN                 3
# 55        0.000            NaN                 4
# 56        0.000            NaN                 5
# ..          ...            ...               ...
# 47        0.000            NaN              1285
# 48        0.000            NaN              1915
# 49        0.000            NaN              2097
# 50        0.000            NaN              2118
# 51        0.001            NaN              2131
#
#                                                 image
# 52  https://specials-images.forbesimg.com/imageser...
# 53  https://specials-images.forbesimg.com/imageser...
# 54  https://specials-images.forbesimg.com/imageser...
# 55  https://specials-images.forbesimg.com/imageser...
# 56  https://specials-images.forbesimg.com/imageser...
# ..                                                ...
# 47  https://specials-images.forbesimg.com/imageser...
# 48  https://specials-images.forbesimg.com/imageser...
# 49  https://specials-images.forbesimg.com/imageser...
# 50  https://specials-images.forbesimg.com/imageser...
# 51  https://specials-images.forbesimg.com/imageser...
#
# [2260 rows x 13 columns]

# %%
null_displ = full_df[(full_df['position'].isnull()==True)]

# %%
full_df.dropna(subset=['position'], inplace=True)

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2208 entries, 52 to 2259
# Data columns (total 13 columns):
# position            2208 non-null float64
# name                2208 non-null object
# lastName            2208 non-null object
# age                 2143 non-null float64
# country             2208 non-null object
# gender              2195 non-null object
# wealthSource        2208 non-null object
# industry            2208 non-null object
# worth               2208 non-null float64
# worthChange         2101 non-null float64
# realTimeWorth       0 non-null float64
# realTimePosition    2208 non-null int64
# image               2208 non-null object
# dtypes: float64(5), int64(1), object(7)
# memory usage: 241.5+ KB
