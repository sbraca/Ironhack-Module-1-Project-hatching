# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine
# !pip install sqlalchemy
import pymysql
from sqlalchemy import create_engine
# Out:
# Requirement already satisfied: sqlalchemy in /Users/Stefania/opt/anaconda3/envs/data_env/lib/python3.7/site-packages (1.3.10)

# %%
engine = create_engine('sqlite:////Users/Stefania/downloads/stefaniabraca.db')

# %%
query = "select * from personal_info"
dfpersonal_info = pd.read_sql_query(query, engine)
query = "select * from business_info"
dfbusiness_info = pd.read_sql_query(query, engine)
query = "select * from rank_info"
dfrank_info = pd.read_sql_query(query, engine)

# %% [markdown]
# # Merge Tables To Build DF

# %%
def get_main_data(df1, df2, df3):
    merged_df = df1.merge(df2, on='id')
    final_df = merged_df.merge(df3, on='id')
    return final_df

# %%
#variable
final_df = get_main_data(dfrank_info, dfbusiness_info, dfpersonal_info)
final_df
# Out:
#         id             name  position  Unnamed: 0_x  Unnamed: 0_y  \
# 0     5227       jeff BEZos       1.0            52            52
# 1     2642       bill GATES       2.0            53            53
# 2     5422   warrEN BUFFEtt       3.0            54            54
# 3     8183  bernarD ARNAULT       4.0            55            55
# 4     5642  mark zUCKERBerg       5.0            56            56
# ...    ...              ...       ...           ...           ...
# 2203  7670   zHAO XIAOQIANG    2204.0          2255          2255
# 2204  1310  zhOU LIANGZHang    2205.0          2256          2256
# 2205  4488     zhu XINGMING    2206.0          2257          2257
# 2206  7152         ZHUO JUn    2207.0          2258          2258
# 2207  7214      OLGUN ZORlu    2208.0          2259          2259
#
#                                                Source       worth  \
# 0                              Technology  ==> Amazon  112.0 BUSD
# 1                           Technology  ==> Microsoft   90.0 BUSD
# 2     Finance and Investments  ==> Berkshire Hathaway   84.0 BUSD
# 3                          Fashion & Retail  ==> LVMH   72.0 BUSD
# 4                            Technology  ==> Facebook   71.0 BUSD
# ...                                               ...         ...
# 2203     Fashion & Retail  ==> fashion, entertainment    1.0 BUSD
# 2204          Manufacturing  ==> electrical equipment    1.0 BUSD
# 2205          Manufacturing  ==> electrical equipment    1.0 BUSD
# 2206        Manufacturing  ==> printed circuit boards    1.0 BUSD
# 2207                     Diversified  ==> diversified    1.0 BUSD
#
#               worthChange realTimeWorth  realTimePosition    lastName  \
# 0        0.0 millions USD          None                 1       bEZOS
# 1     -0.001 millions USD          None                 2       GATES
# 2     -0.002 millions USD          None                 3     bufFETT
# 3        0.0 millions USD          None                 4     aRNAULt
# 4        0.0 millions USD          None                 5  zuckeRBERG
# ...                   ...           ...               ...         ...
# 2203     0.0 millions USD          None              2134        zhAO
# 2204     nan millions USD          None              2134        zhOU
# 2205     0.0 millions USD          None              1856         zHU
# 2206     0.0 millions USD          None              1978        zhUO
# 2207     nan millions USD          None              1978       zORLU
#
#                age  Unnamed: 0  gender        country  \
# 0     54 years old          52    None  United States
# 1     62 years old          53       M           None
# 2     87 years old          54       M           None
# 3     69 years old          55       M         France
# 4             1985          56       M            USA
# ...            ...         ...     ...            ...
# 2203  51 years old        2255    None          China
# 2204  55 years old        2256       M          China
# 2205  51 years old        2257       M           None
# 2206  52 years old        2258  Female      Hong Kong
# 2207  54 years old        2259    None         Turkey
#
#                                                   image
# 0     https://specials-images.forbesimg.com/imageser...
# 1     https://specials-images.forbesimg.com/imageser...
# 2     https://specials-images.forbesimg.com/imageser...
# 3     https://specials-images.forbesimg.com/imageser...
# 4     https://specials-images.forbesimg.com/imageser...
# ...                                                 ...
# 2203  https://specials-images.forbesimg.com/imageser...
# 2204  https://specials-images.forbesimg.com/imageser...
# 2205  https://specials-images.forbesimg.com/imageser...
# 2206  https://specials-images.forbesimg.com/imageser...
# 2207  https://specials-images.forbesimg.com/imageser...
#
# [2208 rows x 16 columns]

# %% [markdown]
# # Drop Columns

# %%
def drop(df, list_col_todrop):
    # drop
    df.drop(list_col_todrop, axis=1, inplace=True)
    
    #cols = list(final_df.columns.values)
    #cols = ['id', 'name', 'lastName', 'position', 'worth', 'Source', 'age', 'gender', 'country', 'image']
    #final_df = final_df.reindex(columns=cols)
    return df

# %%
#variable
col_todrop = ['worthChange', 'Unnamed: 0_x', 'Unnamed: 0_y', 'realTimeWorth', 'realTimePosition', 'Unnamed: 0', 'image']
#function "drop"
final_df = drop(final_df, col_todrop)

# %% [markdown]
# ## Separate 'name' Column

# %%
def new_name (df):
    col=df["name"].str.split(" ", n = 1, expand = True) 
    df["First Name"]= col[0]
    df["Last Name"]= col[1] 
    return df

# %%
new_name(final_df)
# Out:
#         id             name  position  \
# 0     5227       jeff BEZos       1.0
# 1     2642       bill GATES       2.0
# 2     5422   warrEN BUFFEtt       3.0
# 3     8183  bernarD ARNAULT       4.0
# 4     5642  mark zUCKERBerg       5.0
# ...    ...              ...       ...
# 2203  7670   zHAO XIAOQIANG    2204.0
# 2204  1310  zhOU LIANGZHang    2205.0
# 2205  4488     zhu XINGMING    2206.0
# 2206  7152         ZHUO JUn    2207.0
# 2207  7214      OLGUN ZORlu    2208.0
#
#                                                Source       worth    lastName  \
# 0                              Technology  ==> Amazon  112.0 BUSD       bEZOS
# 1                           Technology  ==> Microsoft   90.0 BUSD       GATES
# 2     Finance and Investments  ==> Berkshire Hathaway   84.0 BUSD     bufFETT
# 3                          Fashion & Retail  ==> LVMH   72.0 BUSD     aRNAULt
# 4                            Technology  ==> Facebook   71.0 BUSD  zuckeRBERG
# ...                                               ...         ...         ...
# 2203     Fashion & Retail  ==> fashion, entertainment    1.0 BUSD        zhAO
# 2204          Manufacturing  ==> electrical equipment    1.0 BUSD        zhOU
# 2205          Manufacturing  ==> electrical equipment    1.0 BUSD         zHU
# 2206        Manufacturing  ==> printed circuit boards    1.0 BUSD        zhUO
# 2207                     Diversified  ==> diversified    1.0 BUSD       zORLU
#
#                age  gender        country First Name   Last Name
# 0     54 years old    None  United States       jeff       BEZos
# 1     62 years old       M           None       bill       GATES
# 2     87 years old       M           None     warrEN     BUFFEtt
# 3     69 years old       M         France    bernarD     ARNAULT
# 4             1985       M            USA       mark  zUCKERBerg
# ...            ...     ...            ...        ...         ...
# 2203  51 years old    None          China       zHAO   XIAOQIANG
# 2204  55 years old       M          China       zhOU  LIANGZHang
# 2205  51 years old       M           None        zhu    XINGMING
# 2206  52 years old  Female      Hong Kong       ZHUO         JUn
# 2207  54 years old    None         Turkey      OLGUN       ZORlu
#
# [2208 rows x 11 columns]

# %%
def format_data(df): 

    for i in range(df.shape[0]): 
        df.iat[i, 1]= df.iat[i, 1].strip().capitalize() 
        df.iat[i, 5]= df.iat[i, 5].strip().capitalize()
        df.iat[i, 9]= df.iat[i, 9].strip().capitalize() 
  

format_data(final_df) 
final_df.head()
# Out:
#      id             name  position  \
# 0  5227       Jeff bezos       1.0
# 1  2642       Bill gates       2.0
# 2  5422   Warren buffett       3.0
# 3  8183  Bernard arnault       4.0
# 4  5642  Mark zuckerberg       5.0
#
#                                             Source       worth    lastName  \
# 0                           Technology  ==> Amazon  112.0 BUSD       Bezos
# 1                        Technology  ==> Microsoft   90.0 BUSD       Gates
# 2  Finance and Investments  ==> Berkshire Hathaway   84.0 BUSD     Buffett
# 3                       Fashion & Retail  ==> LVMH   72.0 BUSD     Arnault
# 4                         Technology  ==> Facebook   71.0 BUSD  Zuckerberg
#
#             age gender        country First Name   Last Name
# 0  54 years old   None  United States       Jeff       BEZos
# 1  62 years old      M           None       Bill       GATES
# 2  87 years old      M           None     Warren     BUFFEtt
# 3  69 years old      M         France    Bernard     ARNAULT
# 4          1985      M            USA       Mark  zUCKERBerg

# %% [markdown]
# # Drop Columns

# %%
name_drop = ['name', 'Last Name', 'id' ]

# %%
final_df = drop(final_df, name_drop)

# %%
final_df.head()
# Out:
#    position                                           Source       worth  \
# 0       1.0                           Technology  ==> Amazon  112.0 BUSD
# 1       2.0                        Technology  ==> Microsoft   90.0 BUSD
# 2       3.0  Finance and Investments  ==> Berkshire Hathaway   84.0 BUSD
# 3       4.0                       Fashion & Retail  ==> LVMH   72.0 BUSD
# 4       5.0                         Technology  ==> Facebook   71.0 BUSD
#
#      lastName           age gender        country First Name
# 0       Bezos  54 years old   None  United States       Jeff
# 1       Gates  62 years old      M           None       Bill
# 2     Buffett  87 years old      M           None     Warren
# 3     Arnault  69 years old      M         France    Bernard
# 4  Zuckerberg          1985      M            USA       Mark

# %% [markdown]
# # Re-indexing Columns

# %%
reindex_col = ['position', 'worth', 'First Name', 'lastName', 'age', 'gender', 'Source', 'country']

# %%
def reindex (df, list):
    df = df.reindex(columns=list)
    newlist = [w.title() for w in list]
    df.columns = newlist
    return df

# %% [markdown]
# # (Javi's Pipeline)

# %%
#def loquesea (x):    
#    e = reindex(x)
#    y = hola(e)

# %%
final_df = reindex(final_df, reindex_col)

# %% [markdown]
# # Gender

# %%
final_df.Gender.unique()
# Out:
# array(['None', 'M', 'Male', 'F', None, 'Female'], dtype=object)

# %%
null_cols = final_df.isnull().sum()
null_cols
null_cols[null_cols > 0]
# Out:
# Age       65
# Gender    13
# dtype: int64

# %%
null_displ = final_df[(final_df['Gender'].isnull()==True)]

# %%
null_displ
# Out:
#       Position      Worth First Name       Lastname           Age Gender  \
# 26        27.0  29.8 BUSD      Beate   Albrecht jr.  66 years old   None
# 163      164.0   9.3 BUSD  Gianluigi         Aponte  77 years old   None
# 224      225.0   7.1 BUSD      Willi       Liebherr          None   None
# 309      310.0   5.8 BUSD        Tom           Love  81 years old   None
# 426      427.0   4.8 BUSD     Philip          Green  66 years old   None
# 529      530.0   4.1 BUSD       Jack     Dangermond  72 years old   None
# 581      582.0   3.9 BUSD    Stewart        Resnick          None   None
# 596      597.0   3.8 BUSD   Dominika        Kulczyk          None   None
# 731      732.0   3.2 BUSD     Andrew         Cherng          None   None
# 766      767.0   3.1 BUSD         Do          Chang  62 years old   None
# 1197    1198.0   2.1 BUSD        Ong  Ong beng seng  73 years old   None
# 1260    1261.0   2.0 BUSD    Chuchat      Petaumpai  65 years old   None
# 1290    1291.0   1.9 BUSD  Jean-paul         Clozel          None   None
#
#                                              Source      Country
# 26               Fashion & Retail  ==> supermarkets      Germany
# 163                         Logistics  ==> Shipping         None
# 224    Construction & Engineering  ==> Construction         None
# 309     Fashion & Retail  ==> retail & gas stations          USA
# 426            Fashion & Retail  ==> fashion retail         None
# 529                Technology  ==> mapping software         None
# 581       Food and Beverage  ==> agriculture, water         None
# 596        Finance and Investments  ==> diversified         None
# 731              Food and Beverage  ==> restaurants         None
# 766            Fashion & Retail  ==> fashion retail         None
# 1197                   Diversified  ==> diversified         None
# 1260  Finance and Investments  ==> motorcycle loans         None
# 1290                Healthcare  ==> pharmaceuticals  Switzerland

# %%
final_df.Gender.unique()
# Out:
# array(['None', 'M', 'Male', 'F', None, 'Female'], dtype=object)

# %%
final_df.isnull().sum(axis = 0)
# Out:
# Position       0
# Worth          0
# First Name     0
# Lastname       0
# Age           65
# Gender        13
# Source         0
# Country        0
# dtype: int64

# %%
#13 gender Nulls (NaN) index 26 and 596 are female

# %%
#final_df.loc[26, 'Gender']='Female'
#display(final_df.loc[26, 'Gender'])

# %%
#final_df.loc[596, 'Gender']='Female'
#display(final_df.loc[596, 'Gender'])

# %%
#11 (rest) Gender NaN are Male

# %%
#final_df["Gender"].fillna("Male", inplace = True)

# %%
def gender (df):
    df.loc[26, 'Gender']='Female'
    df.loc[596, 'Gender']='Female'
    df["Gender"].fillna("Male", inplace = True) 
    df.astype({'Gender': str}).dtypes
    return df

# %%
gender(final_df)
# Out:
#       Position       Worth First Name    Lastname           Age  Gender  \
# 0          1.0  112.0 BUSD       Jeff       Bezos  54 years old    None
# 1          2.0   90.0 BUSD       Bill       Gates  62 years old       M
# 2          3.0   84.0 BUSD     Warren     Buffett  87 years old       M
# 3          4.0   72.0 BUSD    Bernard     Arnault  69 years old       M
# 4          5.0   71.0 BUSD       Mark  Zuckerberg          1985       M
# ...        ...         ...        ...         ...           ...     ...
# 2203    2204.0    1.0 BUSD       Zhao        Zhao  51 years old    None
# 2204    2205.0    1.0 BUSD       Zhou        Zhou  55 years old       M
# 2205    2206.0    1.0 BUSD        Zhu         Zhu  51 years old       M
# 2206    2207.0    1.0 BUSD       Zhuo        Zhuo  52 years old  Female
# 2207    2208.0    1.0 BUSD      Olgun       Zorlu  54 years old    None
#
#                                                Source        Country
# 0                              Technology  ==> Amazon  United States
# 1                           Technology  ==> Microsoft           None
# 2     Finance and Investments  ==> Berkshire Hathaway           None
# 3                          Fashion & Retail  ==> LVMH         France
# 4                            Technology  ==> Facebook            USA
# ...                                               ...            ...
# 2203     Fashion & Retail  ==> fashion, entertainment          China
# 2204          Manufacturing  ==> electrical equipment          China
# 2205          Manufacturing  ==> electrical equipment           None
# 2206        Manufacturing  ==> printed circuit boards      Hong Kong
# 2207                     Diversified  ==> diversified         Turkey
#
# [2208 rows x 8 columns]

# %%
final_df.Gender.unique()
# Out:
# array(['None', 'M', 'Male', 'F', 'Female'], dtype=object)

# %%
def gender_cat (df):
    df.loc[df['Gender'].str.startswith('M'), 'Gender_cat'] = 'Male'
    df.loc[df['Gender'].str.startswith('F'), 'Gender_cat'] = 'Female'
    df[['Gender_cat']] = df[['Gender_cat']].fillna('Not Available')
    df.drop('Gender', axis=1, inplace=True)
    
    return df

# %%
#Gender Value=M to Male
#final_df.loc[final_df['Gender'].str.startswith('M'), 'Gender_cat'] = 'Male'

# %%
#Gender Value=F to Female
#final_df.loc[final_df['Gender'].str.startswith('F'), 'Gender_cat'] = 'Female'

# %%
#Gender Value nan
#null_displ = final_df[(final_df['Gender_cat'].isnull()==True)]

# %%
#Gender Value nana to Not Available
#final_df[['Gender_cat']] = final_df[['Gender_cat']].fillna('Not Available')

# %%
gender_cat(final_df)
# Out:
#       Position       Worth First Name    Lastname           Age  \
# 0          1.0  112.0 BUSD       Jeff       Bezos  54 years old
# 1          2.0   90.0 BUSD       Bill       Gates  62 years old
# 2          3.0   84.0 BUSD     Warren     Buffett  87 years old
# 3          4.0   72.0 BUSD    Bernard     Arnault  69 years old
# 4          5.0   71.0 BUSD       Mark  Zuckerberg          1985
# ...        ...         ...        ...         ...           ...
# 2203    2204.0    1.0 BUSD       Zhao        Zhao  51 years old
# 2204    2205.0    1.0 BUSD       Zhou        Zhou  55 years old
# 2205    2206.0    1.0 BUSD        Zhu         Zhu  51 years old
# 2206    2207.0    1.0 BUSD       Zhuo        Zhuo  52 years old
# 2207    2208.0    1.0 BUSD      Olgun       Zorlu  54 years old
#
#                                                Source        Country  \
# 0                              Technology  ==> Amazon  United States
# 1                           Technology  ==> Microsoft           None
# 2     Finance and Investments  ==> Berkshire Hathaway           None
# 3                          Fashion & Retail  ==> LVMH         France
# 4                            Technology  ==> Facebook            USA
# ...                                               ...            ...
# 2203     Fashion & Retail  ==> fashion, entertainment          China
# 2204          Manufacturing  ==> electrical equipment          China
# 2205          Manufacturing  ==> electrical equipment           None
# 2206        Manufacturing  ==> printed circuit boards      Hong Kong
# 2207                     Diversified  ==> diversified         Turkey
#
#          Gender_cat
# 0     Not Available
# 1              Male
# 2              Male
# 3              Male
# 4              Male
# ...             ...
# 2203  Not Available
# 2204           Male
# 2205           Male
# 2206         Female
# 2207  Not Available
#
# [2208 rows x 8 columns]

# %% [markdown]
# # POSITION to INT

# %%
final_df.Position = final_df.Position.astype(int)

# %%
final_df
# Out:
#       Position       Worth First Name    Lastname           Age  \
# 0            1  112.0 BUSD       Jeff       Bezos  54 years old
# 1            2   90.0 BUSD       Bill       Gates  62 years old
# 2            3   84.0 BUSD     Warren     Buffett  87 years old
# 3            4   72.0 BUSD    Bernard     Arnault  69 years old
# 4            5   71.0 BUSD       Mark  Zuckerberg          1985
# ...        ...         ...        ...         ...           ...
# 2203      2204    1.0 BUSD       Zhao        Zhao  51 years old
# 2204      2205    1.0 BUSD       Zhou        Zhou  55 years old
# 2205      2206    1.0 BUSD        Zhu         Zhu  51 years old
# 2206      2207    1.0 BUSD       Zhuo        Zhuo  52 years old
# 2207      2208    1.0 BUSD      Olgun       Zorlu  54 years old
#
#                                                Source        Country  \
# 0                              Technology  ==> Amazon  United States
# 1                           Technology  ==> Microsoft           None
# 2     Finance and Investments  ==> Berkshire Hathaway           None
# 3                          Fashion & Retail  ==> LVMH         France
# 4                            Technology  ==> Facebook            USA
# ...                                               ...            ...
# 2203     Fashion & Retail  ==> fashion, entertainment          China
# 2204          Manufacturing  ==> electrical equipment          China
# 2205          Manufacturing  ==> electrical equipment           None
# 2206        Manufacturing  ==> printed circuit boards      Hong Kong
# 2207                     Diversified  ==> diversified         Turkey
#
#          Gender_cat
# 0     Not Available
# 1              Male
# 2              Male
# 3              Male
# 4              Male
# ...             ...
# 2203  Not Available
# 2204           Male
# 2205           Male
# 2206         Female
# 2207  Not Available
#
# [2208 rows x 8 columns]

# %%
final_df.dtypes
# Out:
# Position       int64
# Worth         object
# First Name    object
# Lastname      object
# Age           object
# Source        object
# Country       object
# Gender_cat    object
# dtype: object

# %% [markdown]
# # Age Column

# %%
final_df.Age.unique()
# Out:
# array(['54 years old', '62 years old', '87 years old', '69 years old',
#        '1985', '82 years old', '78 years old', '73 years old',
#        '76 years old', '45 years old', '44 years old', '70 years old',
#        '68 years old', '46 years old', '64 years old', '61 years old',
#        '53 years old', '84 years old', '90 years old', '59 years old',
#        '63 years old', '66 years old', '80 years old', '81 years old',
#        '56 years old', '79 years old', '74 years old', '60 years old',
#        '93 years old', '52 years old', '1983', '65 years old',
#        '83 years old', '67 years old', '75 years old', '89 years old',
#        None, '72 years old', '48 years old', '77 years old',
#        '86 years old', '57 years old', '1988', '55 years old',
#        '94 years old', '47 years old', '71 years old', '92 years old',
#        '88 years old', '85 years old', '49 years old', '51 years old',
#        '50 years old', '43 years old', '42 years old', '91 years old',
#        '58 years old', '1984', '38 years old', '1982', '95 years old',
#        '39 years old', '41 years old', '40 years old', '1990', '1991',
#        '97 years old', '1986', '99 years old', '1994', '1998', '1996',
#        '96 years old', '1987', '1989', '1992'], dtype=object)

# %%
def clean_age (df):
    df = df['Age'].str.replace('years old', '')
    df[['Age']] = df[['Age']].fillna(0)

# %%
#final_df.Age.unique()

# %%
#1
final_df['Age'] = final_df['Age'].str.replace('years old', '')
#nans are back

# %%
#2
final_df[['Age']] = final_df[['Age']].fillna(0)

# %%
final_df.Age.unique()
# Out:
# array(['54 ', '62 ', '87 ', '69 ', '1985', '82 ', '78 ', '73 ', '76 ',
#        '45 ', '44 ', '70 ', '68 ', '46 ', '64 ', '61 ', '53 ', '84 ',
#        '90 ', '59 ', '63 ', '66 ', '80 ', '81 ', '56 ', '79 ', '74 ',
#        '60 ', '93 ', '52 ', '1983', '65 ', '83 ', '67 ', '75 ', '89 ', 0,
#        '72 ', '48 ', '77 ', '86 ', '57 ', '1988', '55 ', '94 ', '47 ',
#        '71 ', '92 ', '88 ', '85 ', '49 ', '51 ', '50 ', '43 ', '42 ',
#        '91 ', '58 ', '1984', '38 ', '1982', '95 ', '39 ', '41 ', '40 ',
#        '1990', '1991', '97 ', '1986', '99 ', '1994', '1998', '1996',
#        '96 ', '1987', '1989', '1992'], dtype=object)

# %%
#def year_toage (series):
 #   if len(x) > 3 lambda x: 2018-x

# %%
def year_toage (df):
    df['Age'] = df['Age'].str.replace('1982', '36')
    df['Age'] = df['Age'].str.replace('1983', '35')
    df['Age'] = df['Age'].str.replace('1984', '34')
    df['Age'] = df['Age'].str.replace('1985', '33')
    df['Age'] = df['Age'].str.replace('1986', '32')
    df['Age'] = df['Age'].str.replace('1987', '31')
    df['Age'] = df['Age'].str.replace('1988', '30')
    df['Age'] = df['Age'].str.replace('1989', '29')
    df['Age'] = df['Age'].str.replace('1990', '28')
    df['Age'] = df['Age'].str.replace('1991', '27')
    df['Age'] = df['Age'].str.replace('1992', '26')
    df['Age'] = df['Age'].str.replace('1994', '24')
    df['Age'] = df['Age'].str.replace('1996', '22')
    df['Age'] = df['Age'].str.replace('1998', '20')
    return df

# %%
year_toage (final_df)
# Out:
#       Position       Worth First Name    Lastname  Age  \
# 0            1  112.0 BUSD       Jeff       Bezos  54
# 1            2   90.0 BUSD       Bill       Gates  62
# 2            3   84.0 BUSD     Warren     Buffett  87
# 3            4   72.0 BUSD    Bernard     Arnault  69
# 4            5   71.0 BUSD       Mark  Zuckerberg   33
# ...        ...         ...        ...         ...  ...
# 2203      2204    1.0 BUSD       Zhao        Zhao  51
# 2204      2205    1.0 BUSD       Zhou        Zhou  55
# 2205      2206    1.0 BUSD        Zhu         Zhu  51
# 2206      2207    1.0 BUSD       Zhuo        Zhuo  52
# 2207      2208    1.0 BUSD      Olgun       Zorlu  54
#
#                                                Source        Country  \
# 0                              Technology  ==> Amazon  United States
# 1                           Technology  ==> Microsoft           None
# 2     Finance and Investments  ==> Berkshire Hathaway           None
# 3                          Fashion & Retail  ==> LVMH         France
# 4                            Technology  ==> Facebook            USA
# ...                                               ...            ...
# 2203     Fashion & Retail  ==> fashion, entertainment          China
# 2204          Manufacturing  ==> electrical equipment          China
# 2205          Manufacturing  ==> electrical equipment           None
# 2206        Manufacturing  ==> printed circuit boards      Hong Kong
# 2207                     Diversified  ==> diversified         Turkey
#
#          Gender_cat
# 0     Not Available
# 1              Male
# 2              Male
# 3              Male
# 4              Male
# ...             ...
# 2203  Not Available
# 2204           Male
# 2205           Male
# 2206         Female
# 2207  Not Available
#
# [2208 rows x 8 columns]

# %%
final_df.Age.unique()
# Out:
# array(['54 ', '62 ', '87 ', '69 ', '33', '82 ', '78 ', '73 ', '76 ',
#        '45 ', '44 ', '70 ', '68 ', '46 ', '64 ', '61 ', '53 ', '84 ',
#        '90 ', '59 ', '63 ', '66 ', '80 ', '81 ', '56 ', '79 ', '74 ',
#        '60 ', '93 ', '52 ', '35', '65 ', '83 ', '67 ', '75 ', '89 ', nan,
#        '72 ', '48 ', '77 ', '86 ', '57 ', '30', '55 ', '94 ', '47 ',
#        '71 ', '92 ', '88 ', '85 ', '49 ', '51 ', '50 ', '43 ', '42 ',
#        '91 ', '58 ', '34', '38 ', '36', '95 ', '39 ', '41 ', '40 ', '28',
#        '27', '97 ', '32', '99 ', '24', '20', '22', '96 ', '31', '29',
#        '26'], dtype=object)

# %%
def nan_toage (df):
    df[['Age']] = df[['Age']].fillna(0)
    df.Age = df.Age.astype(int)
    mean= df['Age'].mean()
    df.replace({'Age': {0: 'mean'}})
    return df

# %%
nan_toage(final_df)
# Out:
#       Position       Worth First Name    Lastname  Age  \
# 0            1  112.0 BUSD       Jeff       Bezos   54
# 1            2   90.0 BUSD       Bill       Gates   62
# 2            3   84.0 BUSD     Warren     Buffett   87
# 3            4   72.0 BUSD    Bernard     Arnault   69
# 4            5   71.0 BUSD       Mark  Zuckerberg   33
# ...        ...         ...        ...         ...  ...
# 2203      2204    1.0 BUSD       Zhao        Zhao   51
# 2204      2205    1.0 BUSD       Zhou        Zhou   55
# 2205      2206    1.0 BUSD        Zhu         Zhu   51
# 2206      2207    1.0 BUSD       Zhuo        Zhuo   52
# 2207      2208    1.0 BUSD      Olgun       Zorlu   54
#
#                                                Source        Country  \
# 0                              Technology  ==> Amazon  United States
# 1                           Technology  ==> Microsoft           None
# 2     Finance and Investments  ==> Berkshire Hathaway           None
# 3                          Fashion & Retail  ==> LVMH         France
# 4                            Technology  ==> Facebook            USA
# ...                                               ...            ...
# 2203     Fashion & Retail  ==> fashion, entertainment          China
# 2204          Manufacturing  ==> electrical equipment          China
# 2205          Manufacturing  ==> electrical equipment           None
# 2206        Manufacturing  ==> printed circuit boards      Hong Kong
# 2207                     Diversified  ==> diversified         Turkey
#
#          Gender_cat
# 0     Not Available
# 1              Male
# 2              Male
# 3              Male
# 4              Male
# ...             ...
# 2203  Not Available
# 2204           Male
# 2205           Male
# 2206         Female
# 2207  Not Available
#
# [2208 rows x 8 columns]

# %%
final_df.Age.unique()
# Out:
# array([54, 62, 87, 69, 33, 82, 78, 73, 76, 45, 44, 70, 68, 46, 64, 61, 53,
#        84, 90, 59, 63, 66, 80, 81, 56, 79, 74, 60, 93, 52, 35, 65, 83, 67,
#        75, 89,  0, 72, 48, 77, 86, 57, 30, 55, 94, 47, 71, 92, 88, 85, 49,
#        51, 50, 43, 42, 91, 58, 34, 38, 36, 95, 39, 41, 40, 28, 27, 97, 32,
#        99, 24, 20, 22, 96, 31, 29, 26])

# %% [markdown]
# # COUNTRY Column

# %%
final_df.Country.unique()
# Out:
# array(['United States', 'None', 'France', 'USA', 'Mexico',
#        "People's Republic of China", 'Hong Kong', 'Germany', 'Canada',
#        'China', 'Russia', 'South Korea', 'Ireland', 'Indonesia',
#        'Australia', 'Czech Republic', 'India', 'Brazil', 'Italy',
#        'New Zealand', 'Israel', 'Switzerland', 'Austria', 'Sweden',
#        'Cyprus', 'Spain', 'Norway', 'United Kingdom',
#        'United Arab Emirates', 'Philippines', 'Denmark', 'Netherlands',
#        'Portugal', 'Japan', 'Swaziland', 'Vietnam', 'Thailand', 'Oman',
#        'UK', 'Colombia', 'Malaysia', 'Kazakhstan', 'Poland', 'Singapore',
#        'Greece', 'Chile', 'Taiwan', 'Turkey', 'South Africa', 'Angola',
#        'Guernsey', 'Finland', 'Iceland', 'Egypt', 'Monaco', 'Peru',
#        'Argentina', 'Qatar', 'Lebanon', 'St. Kitts and Nevis', 'Nigeria',
#        'Tanzania', 'Ukraine', 'Slovakia', 'Venezuela'], dtype=object)

# %%
final_df.Country = final_df.Country.astype(str)

# %%
final_df['Country'].value_counts()
# Out:
# None             1386
# United States     200
# China             116
# USA                67
# Germany            45
#                  ...
# Malaysia            1
# New Zealand         1
# Oman                1
# Swaziland           1
# Monaco              1
# Name: Country, Length: 65, dtype: int64

# %%
def clean_country (df):
    df['Country'] = df['Country'].str.replace('USA', 'United States')
    df['Country'] = df['Country'].str.replace("People's Republic of China", 'China')
    return df

# %%
clean_country(final_df)
# Out:
#       Position       Worth First Name    Lastname  Age  \
# 0            1  112.0 BUSD       Jeff       Bezos   54
# 1            2   90.0 BUSD       Bill       Gates   62
# 2            3   84.0 BUSD     Warren     Buffett   87
# 3            4   72.0 BUSD    Bernard     Arnault   69
# 4            5   71.0 BUSD       Mark  Zuckerberg   33
# ...        ...         ...        ...         ...  ...
# 2203      2204    1.0 BUSD       Zhao        Zhao   51
# 2204      2205    1.0 BUSD       Zhou        Zhou   55
# 2205      2206    1.0 BUSD        Zhu         Zhu   51
# 2206      2207    1.0 BUSD       Zhuo        Zhuo   52
# 2207      2208    1.0 BUSD      Olgun       Zorlu   54
#
#                                                Source        Country  \
# 0                              Technology  ==> Amazon  United States
# 1                           Technology  ==> Microsoft           None
# 2     Finance and Investments  ==> Berkshire Hathaway           None
# 3                          Fashion & Retail  ==> LVMH         France
# 4                            Technology  ==> Facebook  United States
# ...                                               ...            ...
# 2203     Fashion & Retail  ==> fashion, entertainment          China
# 2204          Manufacturing  ==> electrical equipment          China
# 2205          Manufacturing  ==> electrical equipment           None
# 2206        Manufacturing  ==> printed circuit boards      Hong Kong
# 2207                     Diversified  ==> diversified         Turkey
#
#          Gender_cat
# 0     Not Available
# 1              Male
# 2              Male
# 3              Male
# 4              Male
# ...             ...
# 2203  Not Available
# 2204           Male
# 2205           Male
# 2206         Female
# 2207  Not Available
#
# [2208 rows x 8 columns]

# %% [markdown]
# # WEB SCRP TOP10

# %%
import requests
# !pip install BeautifulSoup4
# !pip install lxml
from bs4 import BeautifulSoup
import pandas as pd
# Out:
# Requirement already satisfied: BeautifulSoup4 in /Users/Stefania/opt/anaconda3/envs/data_env/lib/python3.7/site-packages (4.8.2)
# Requirement already satisfied: soupsieve>=1.2 in /Users/Stefania/opt/anaconda3/envs/data_env/lib/python3.7/site-packages (from BeautifulSoup4) (1.9.5)
# Requirement already satisfied: lxml in /Users/Stefania/opt/anaconda3/envs/data_env/lib/python3.7/site-packages (4.4.2)

# %%
#Variables:
url = 'https://en.wikipedia.org/wiki/The_World%27s_Billionaires'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

# %%
def scr_top10 (url, html, soup):
    table = soup.find_all('table',{'class':'wikitable sortable'})[0]
    return table

# %%
table = scr_top10(url, html, soup)

# %%
def scr_table (table):
    rows = table.find_all('tr')
    rows_parsed = [row.text for row in rows]
    rows = [row.text.strip().split("\n") for row in rows]
    colnames = rows[0]
    for ele in colnames: 
        if ele == (''): 
            colnames.remove(ele) 
    data = rows[1:]
    top10_df = pd.DataFrame(data, columns=colnames)
    top10_df.drop(columns=['Name', 'Net worth (USD)','Age', 'Source(s) of wealth'], inplace=True)
    top10_df.rename(columns={"No.": "Position"}, inplace=True)
    
  
    return top10_df

# %%
top10_df = scr_table(table)
top10_df
# Out:
#   Position     Nationality
# 0       1    United States
# 1       2    United States
# 2       3    United States
# 3       4           France
# 4       5           Mexico
# 5       6            Spain
# 6       7    United States
# 7       8    United States
# 8       9    United States
# 9      10    United States

# %%
top10_df = top10_df.astype({"Position": int})

# %%
def merge1 (df1,df2):
    merged_df = pd.merge(df1, df2, on='Position', how='outer')
    return merged_df

# %%
merged_df = merge1(final_df, top10_df)

# %%
top10_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
# Position       10 non-null int64
# Nationality    10 non-null object
# dtypes: int64(1), object(1)
# memory usage: 288.0+ bytes

# %%
merged_df.head()
# Out:
#    Position       Worth First Name    Lastname  Age  \
# 0         1  112.0 BUSD       Jeff       Bezos   54
# 1         2   90.0 BUSD       Bill       Gates   62
# 2         3   84.0 BUSD     Warren     Buffett   87
# 3         4   72.0 BUSD    Bernard     Arnault   69
# 4         5   71.0 BUSD       Mark  Zuckerberg   33
#
#                                             Source        Country  \
# 0                           Technology  ==> Amazon  United States
# 1                        Technology  ==> Microsoft           None
# 2  Finance and Investments  ==> Berkshire Hathaway           None
# 3                       Fashion & Retail  ==> LVMH         France
# 4                         Technology  ==> Facebook  United States
#
#       Gender_cat     Nationality
# 0  Not Available   United States
# 1           Male   United States
# 2           Male   United States
# 3           Male          France
# 4           Male          Mexico
