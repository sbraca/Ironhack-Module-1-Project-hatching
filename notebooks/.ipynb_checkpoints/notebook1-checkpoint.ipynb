# %%
import pandas as pd

# !pip install sqlalchemy

# %%
import pymysql
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:////Users/Stefania/downloads/stefaniabraca.db')

# %% [markdown]
# # dfpersonal_info

# %%
query = "select * from personal_info"
dfpersonal_info = pd.read_sql_query(query, engine)
dfpersonal_info.head(15)
# Out:
#       id    lastName           age  Unnamed: 0 gender        country  \
# 0   5227       bEZOS  54 years old          52   None  United States
# 1   2642       GATES  62 years old          53      M           None
# 2   5422     bufFETT  87 years old          54      M           None
# 3   8183     aRNAULt  69 years old          55      M         France
# 4   5642  zuckeRBERG          1985          56      M            USA
# 5   1690      ortEGa  82 years old          57      M           None
# 6   2877   sLIM Helu  78 years old          58   None         Mexico
# 7   1939        koCH  82 years old          59      M  United States
# 8   9011        kOCH  78 years old          60   Male            USA
# 9   7523     elLISOn  73 years old          61      M           None
# 10  8133   blOOMBERG  76 years old          62   Male           None
# 11  8447        pAGE  45 years old          63   None           None
# 12  5897        BRIN  44 years old          64      M  United States
# ...

# %%
dfpersonal_info.columns
# Out:
# Index(['id', 'lastName', 'age', 'Unnamed: 0', 'gender', 'country', 'image'], dtype='object')

# %%
dfpersonal_info_column_names = dfpersonal_info.columns

# %%
for i in dfpersonal_info_column_names:
  print('{} is unique: {}'.format(i, dfpersonal_info[i].is_unique))
# Out:
# id is unique: True
# lastName is unique: False
# age is unique: False
# Unnamed: 0 is unique: True
# gender is unique: False
# country is unique: False
# image is unique: False

# %%
dfpersonal_info.dtypes
# Out:
# id             int64
# lastName      object
# age           object
# Unnamed: 0     int64
# gender        object
# country       object
# image         object
# dtype: object

# %%
dfpersonal_info.index.values
# Out:
# array([   0,    1,    2, ..., 2205, 2206, 2207])

# %% [markdown]
# # dfbusiness_info

# %%
query = "select * from business_info"
dfbusiness_info = pd.read_sql_query(query, engine)
dfbusiness_info.head(15)
# Out:
#       id  Unnamed: 0                                           Source  \
# 0   5227          52                           Technology  ==> Amazon
# 1   2642          53                        Technology  ==> Microsoft
# 2   5422          54  Finance and Investments  ==> Berkshire Hathaway
# 3   8183          55                       Fashion & Retail  ==> LVMH
# 4   5642          56                         Technology  ==> Facebook
# 5   1690          57                       Fashion & Retail  ==> Zara
# 6   2877          58                             Telecom  ==> telecom
# 7   1939          59                 Diversified  ==> Koch Industries
# 8   9011          60                 Diversified  ==> Koch Industries
# 9   7523          61                         Technology  ==> software
# 10  8133          62          Media & Entertainment  ==> Bloomberg LP
# 11  8447          63                           Technology  ==> Google
# ...

# %%
dfbusiness_info_column_names = dfbusiness_info.columns
print(dfbusiness_info_column_names)
# Out:
# Index(['id', 'Unnamed: 0', 'Source', 'worth', 'worthChange', 'realTimeWorth',
#        'realTimePosition'],
#       dtype='object')

# %%
dfbusiness_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2208 entries, 0 to 2207
# Data columns (total 7 columns):
# id                  2208 non-null int64
# Unnamed: 0          2208 non-null int64
# Source              2208 non-null object
# worth               2208 non-null object
# worthChange         2208 non-null object
# realTimeWorth       0 non-null object
# realTimePosition    2208 non-null int64
# dtypes: int64(3), object(4)
# memory usage: 120.9+ KB

# %%
dfbusiness_info.isnull()
# Out:
#          id  Unnamed: 0  Source  worth  worthChange  realTimeWorth  \
# 0     False       False   False  False        False           True
# 1     False       False   False  False        False           True
# 2     False       False   False  False        False           True
# 3     False       False   False  False        False           True
# 4     False       False   False  False        False           True
# ...     ...         ...     ...    ...          ...            ...
# 2203  False       False   False  False        False           True
# 2204  False       False   False  False        False           True
# 2205  False       False   False  False        False           True
# 2206  False       False   False  False        False           True
# 2207  False       False   False  False        False           True
#
#       realTimePosition
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ...

# %%
dfbusiness_info.isnull().sum()
# Out:
# id                     0
# Unnamed: 0             0
# Source                 0
# worth                  0
# worthChange            0
# realTimeWorth       2208
# realTimePosition       0
# dtype: int64

# %%
dfbusiness_info.isnull().sum() > 0
# Out:
# id                  False
# Unnamed: 0          False
# Source              False
# worth               False
# worthChange         False
# realTimeWorth        True
# realTimePosition    False
# dtype: bool

# %%
 dfbusiness_info.head()
# Out:
#      id  Unnamed: 0                                           Source  \
# 0  5227          52                           Technology  ==> Amazon
# 1  2642          53                        Technology  ==> Microsoft
# 2  5422          54  Finance and Investments  ==> Berkshire Hathaway
# 3  8183          55                       Fashion & Retail  ==> LVMH
# 4  5642          56                         Technology  ==> Facebook
#
#         worth          worthChange realTimeWorth  realTimePosition
# 0  112.0 BUSD     0.0 millions USD          None                 1
# 1   90.0 BUSD  -0.001 millions USD          None                 2
# 2   84.0 BUSD  -0.002 millions USD          None                 3
# 3   72.0 BUSD     0.0 millions USD          None                 4
# 4   71.0 BUSD     0.0 millions USD          None                 5

# %%
dfbusiness_info.drop('realTimeWorth', axis=1, inplace=True)

# %%
dfbusiness_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2208 entries, 0 to 2207
# Data columns (total 6 columns):
# id                  2208 non-null int64
# Unnamed: 0          2208 non-null int64
# Source              2208 non-null object
# worth               2208 non-null object
# worthChange         2208 non-null object
# realTimePosition    2208 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 103.6+ KB

# %%
dfbusiness_info_column_names = dfbusiness_info.columns

# %%
for i in dfbusiness_info_column_names:
  print('{} is unique: {}'.format(i, dfbusiness_info[i].is_unique))
# Out:
# id is unique: True
# Unnamed: 0 is unique: True
# Source is unique: False
# worth is unique: False
# worthChange is unique: False
# realTimePosition is unique: False

# %%
dfbusiness_info.dtypes
# Out:
# id                   int64
# Unnamed: 0           int64
# Source              object
# worth               object
# worthChange         object
# realTimePosition     int64
# dtype: object

# %%
dfbusiness_info.index.values
# Out:
# array([   0,    1,    2, ..., 2205, 2206, 2207])

# %% [markdown]
# # dfrank_info

# %%
query = "select * from rank_info"
dfrank_info = pd.read_sql_query(query, engine)
dfrank_info.head()
# Out:
#      id                         name  position  Unnamed: 0
# 0  1431  anANT ASAVABHOKHIN & FAmily       NaN           0
# 1  7293               arASH FERDowsi       NaN           1
# 2  3534     banthoON LAMSAM & FAMILy       NaN           2
# 3  2538       bill ADDERLEY & family       NaN           3
# 4  2722            borIS ZINGArevich       NaN           4

# %%
dfrank_info.columns
# Out:
# Index(['id', 'name', 'position', 'Unnamed: 0'], dtype='object')

# %%
dfrank_info_column_names = dfrank_info.columns

# %%
for i in dfrank_info_column_names:
  print('{} is unique: {}'.format(i, dfrank_info[i].is_unique))
# Out:
# id is unique: True
# name is unique: True
# position is unique: False
# Unnamed: 0 is unique: True

# %%
dfrank_info.dtypes
# Out:
# id              int64
# name           object
# position      float64
# Unnamed: 0      int64
# dtype: object

# %%
dfrank_info.index.values
# Out:
# array([   0,    1,    2, ..., 2257, 2258, 2259])

# %% [markdown]
# # Merge

# %%
merged_df = dfrank_info.merge(dfbusiness_info, on='id')

# %%
merged_df.index.values
# Out:
# array([   0,    1,    2, ..., 2205, 2206, 2207])

# %%
final_df = merged_df.merge(dfpersonal_info, on='id')

# %%
final_df.head()
# Out:
#      id             name  position  Unnamed: 0_x  Unnamed: 0_y  \
# 0  5227       jeff BEZos       1.0            52            52
# 1  2642       bill GATES       2.0            53            53
# 2  5422   warrEN BUFFEtt       3.0            54            54
# 3  8183  bernarD ARNAULT       4.0            55            55
# 4  5642  mark zUCKERBerg       5.0            56            56
#
#                                             Source       worth  \
# 0                           Technology  ==> Amazon  112.0 BUSD
# 1                        Technology  ==> Microsoft   90.0 BUSD
# 2  Finance and Investments  ==> Berkshire Hathaway   84.0 BUSD
# 3                       Fashion & Retail  ==> LVMH   72.0 BUSD
# 4                         Technology  ==> Facebook   71.0 BUSD
#
#            worthChange  realTimePosition    lastName           age  \
# 0     0.0 millions USD                 1       bEZOS  54 years old
# 1  -0.001 millions USD                 2       GATES  62 years old
# ...

# %%
#drop duplicated columns

final_df.drop('Unnamed: 0_x', axis=1, inplace=True) 
final_df.drop('Unnamed: 0_y', axis=1, inplace=True)

# %%
final_df.head()
# Out:
#      id             name  position  \
# 0  5227       jeff BEZos       1.0
# 1  2642       bill GATES       2.0
# 2  5422   warrEN BUFFEtt       3.0
# 3  8183  bernarD ARNAULT       4.0
# 4  5642  mark zUCKERBerg       5.0
#
#                                             Source       worth  \
# 0                           Technology  ==> Amazon  112.0 BUSD
# 1                        Technology  ==> Microsoft   90.0 BUSD
# 2  Finance and Investments  ==> Berkshire Hathaway   84.0 BUSD
# 3                       Fashion & Retail  ==> LVMH   72.0 BUSD
# 4                         Technology  ==> Facebook   71.0 BUSD
#
#            worthChange  realTimePosition    lastName           age  \
# 0     0.0 millions USD                 1       bEZOS  54 years old
# 1  -0.001 millions USD                 2       GATES  62 years old
# 2  -0.002 millions USD                 3     bufFETT  87 years old
# 3     0.0 millions USD                 4     aRNAULt  69 years old
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2208 entries, 0 to 2207
# Data columns (total 13 columns):
# id                  2208 non-null int64
# name                2208 non-null object
# position            2208 non-null float64
# Source              2208 non-null object
# worth               2208 non-null object
# worthChange         2208 non-null object
# realTimePosition    2208 non-null int64
# lastName            2208 non-null object
# age                 2143 non-null object
# Unnamed: 0          2208 non-null int64
# gender              2195 non-null object
# country             2208 non-null object
# image               2208 non-null object
# dtypes: float64(1), int64(3), object(9)
# memory usage: 241.5+ KB

# %%
final_df.index.values
# Out:
# array([   0,    1,    2, ..., 2205, 2206, 2207])

# %% [markdown]
# # Reindexing columns

# %%
cols = list(final_df.columns.values)
print(cols)
# Out:
# ['id', 'name', 'position', 'Source', 'worth', 'worthChange', 'realTimePosition', 'lastName', 'age', 'Unnamed: 0', 'gender', 'country', 'image']

# %%
cols = ['id', 'name', 'lastName', 'position', 'worth', 'Source', 'age', 'Unnamed: 0', 'gender', 'country', 'image', 'worthChange']

# %%
final_df = final_df.reindex(columns=cols)

# %%
final_df.head()
# Out:
#      id             name    lastName  position       worth  \
# 0  5227       jeff BEZos       bEZOS       1.0  112.0 BUSD
# 1  2642       bill GATES       GATES       2.0   90.0 BUSD
# 2  5422   warrEN BUFFEtt     bufFETT       3.0   84.0 BUSD
# 3  8183  bernarD ARNAULT     aRNAULt       4.0   72.0 BUSD
# 4  5642  mark zUCKERBerg  zuckeRBERG       5.0   71.0 BUSD
#
#                                             Source           age  Unnamed: 0  \
# 0                           Technology  ==> Amazon  54 years old          52
# 1                        Technology  ==> Microsoft  62 years old          53
# 2  Finance and Investments  ==> Berkshire Hathaway  87 years old          54
# 3                       Fashion & Retail  ==> LVMH  69 years old          55
# 4                         Technology  ==> Facebook          1985          56
#
#   gender        country                                              image  \
# ...

# %%
final_df.drop('worthChange', axis=1, inplace=True) 
final_df.head()
# Out:
#      id             name    lastName  position       worth  \
# 0  5227       jeff BEZos       bEZOS       1.0  112.0 BUSD
# 1  2642       bill GATES       GATES       2.0   90.0 BUSD
# 2  5422   warrEN BUFFEtt     bufFETT       3.0   84.0 BUSD
# 3  8183  bernarD ARNAULT     aRNAULt       4.0   72.0 BUSD
# 4  5642  mark zUCKERBerg  zuckeRBERG       5.0   71.0 BUSD
#
#                                             Source           age  Unnamed: 0  \
# 0                           Technology  ==> Amazon  54 years old          52
# 1                        Technology  ==> Microsoft  62 years old          53
# 2  Finance and Investments  ==> Berkshire Hathaway  87 years old          54
# 3                       Fashion & Retail  ==> LVMH  69 years old          55
# 4                         Technology  ==> Facebook          1985          56
#
#   gender        country                                              image
# ...

# %%
final_df["FullName"] = final_df["name"].map(str) + ' ' + final_df["lastName"]
final_df.head()
# Out:
#      id             name    lastName  position       worth  \
# 0  5227       jeff BEZos       bEZOS       1.0  112.0 BUSD
# 1  2642       bill GATES       GATES       2.0   90.0 BUSD
# 2  5422   warrEN BUFFEtt     bufFETT       3.0   84.0 BUSD
# 3  8183  bernarD ARNAULT     aRNAULt       4.0   72.0 BUSD
# 4  5642  mark zUCKERBerg  zuckeRBERG       5.0   71.0 BUSD
#
#                                             Source           age  Unnamed: 0  \
# 0                           Technology  ==> Amazon  54 years old          52
# 1                        Technology  ==> Microsoft  62 years old          53
# 2  Finance and Investments  ==> Berkshire Hathaway  87 years old          54
# 3                       Fashion & Retail  ==> LVMH  69 years old          55
# 4                         Technology  ==> Facebook          1985          56
#
#   gender        country                                              image  \
# ...

# %%
cols2 = ['id', 'name', 'lastName', 'FullName',  'position', 'worth', 'Source', 'age', 'Unnamed: 0', 'gender', 'country', 'image', 'worthChange']

# %%
final_df = final_df.reindex(columns=cols2)

# %%
final_df.head()
# Out:
#      id             name    lastName                    FullName  position  \
# 0  5227       jeff BEZos       bEZOS            jeff BEZos bEZOS       1.0
# 1  2642       bill GATES       GATES            bill GATES GATES       2.0
# 2  5422   warrEN BUFFEtt     bufFETT      warrEN BUFFEtt bufFETT       3.0
# 3  8183  bernarD ARNAULT     aRNAULt     bernarD ARNAULT aRNAULt       4.0
# 4  5642  mark zUCKERBerg  zuckeRBERG  mark zUCKERBerg zuckeRBERG       5.0
#
#         worth                                           Source           age  \
# 0  112.0 BUSD                           Technology  ==> Amazon  54 years old
# 1   90.0 BUSD                        Technology  ==> Microsoft  62 years old
# 2   84.0 BUSD  Finance and Investments  ==> Berkshire Hathaway  87 years old
# 3   72.0 BUSD                       Fashion & Retail  ==> LVMH  69 years old
# 4   71.0 BUSD                         Technology  ==> Facebook          1985
#
#    Unnamed: 0 gender        country  \
# ...

# %%
final_df.drop('worthChange', axis=1, inplace=True)

# %%
final_df.drop('FullName', axis=1, inplace=True)

# %%
final_df.head()
# Out:
#      id             name    lastName  position       worth  \
# 0  5227       jeff BEZos       bEZOS       1.0  112.0 BUSD
# 1  2642       bill GATES       GATES       2.0   90.0 BUSD
# 2  5422   warrEN BUFFEtt     bufFETT       3.0   84.0 BUSD
# 3  8183  bernarD ARNAULT     aRNAULt       4.0   72.0 BUSD
# 4  5642  mark zUCKERBerg  zuckeRBERG       5.0   71.0 BUSD
#
#                                             Source           age  Unnamed: 0  \
# 0                           Technology  ==> Amazon  54 years old          52
# 1                        Technology  ==> Microsoft  62 years old          53
# 2  Finance and Investments  ==> Berkshire Hathaway  87 years old          54
# 3                       Fashion & Retail  ==> LVMH  69 years old          55
# 4                         Technology  ==> Facebook          1985          56
#
#   gender        country                                              image
# ...

# %%
def format_data(final_df): 

    for i in range(final_df.shape[0]): 
        final_df.iat[i, 1]= final_df.iat[i, 1].strip().capitalize() 
  

format_data(final_df) 

final_df.head()

#final_df.iat[i, 1] "1" is the index of the column
# Out:
#      id             name    lastName  position       worth  \
# 0  5227       Jeff bezos       bEZOS       1.0  112.0 BUSD
# 1  2642       Bill gates       GATES       2.0   90.0 BUSD
# 2  5422   Warren buffett     bufFETT       3.0   84.0 BUSD
# 3  8183  Bernard arnault     aRNAULt       4.0   72.0 BUSD
# 4  5642  Mark zuckerberg  zuckeRBERG       5.0   71.0 BUSD
#
#                                             Source           age  Unnamed: 0  \
# 0                           Technology  ==> Amazon  54 years old          52
# 1                        Technology  ==> Microsoft  62 years old          53
# 2  Finance and Investments  ==> Berkshire Hathaway  87 years old          54
# 3                       Fashion & Retail  ==> LVMH  69 years old          55
# 4                         Technology  ==> Facebook          1985          56
#
#   gender        country                                              image
# ...

# %%
new_name = final_df["name"].str.split(" ", n = 1, expand = True) 

# making separate first name column from new data frame 
final_df["First Name"]= new_name[0] 
  
# making separate last name column from new data frame 
final_df["Last Name"]= new_name[1] 

final_df.head()
# Out:
#      id             name    lastName  position       worth  \
# 0  5227       Jeff bezos       bEZOS       1.0  112.0 BUSD
# 1  2642       Bill gates       GATES       2.0   90.0 BUSD
# 2  5422   Warren buffett     bufFETT       3.0   84.0 BUSD
# 3  8183  Bernard arnault     aRNAULt       4.0   72.0 BUSD
# 4  5642  Mark zuckerberg  zuckeRBERG       5.0   71.0 BUSD
#
#                                             Source           age  Unnamed: 0  \
# 0                           Technology  ==> Amazon  54 years old          52
# 1                        Technology  ==> Microsoft  62 years old          53
# 2  Finance and Investments  ==> Berkshire Hathaway  87 years old          54
# 3                       Fashion & Retail  ==> LVMH  69 years old          55
# 4                         Technology  ==> Facebook          1985          56
#
#   gender        country                                              image  \
# ...

# %%
# Dropping old Name columns 
final_df.drop(columns =["name"], inplace = True)

# %%
def format_data(final_df): 

    for i in range(final_df.shape[0]): 
        final_df.iat[i, 1]= final_df.iat[i, 1].strip().capitalize() 
  

format_data(final_df) 
final_df.head()
# Out:
#      id    lastName  position       worth  \
# 0  5227       Bezos       1.0  112.0 BUSD
# 1  2642       Gates       2.0   90.0 BUSD
# 2  5422     Buffett       3.0   84.0 BUSD
# 3  8183     Arnault       4.0   72.0 BUSD
# 4  5642  Zuckerberg       5.0   71.0 BUSD
#
#                                             Source           age  Unnamed: 0  \
# 0                           Technology  ==> Amazon  54 years old          52
# 1                        Technology  ==> Microsoft  62 years old          53
# 2  Finance and Investments  ==> Berkshire Hathaway  87 years old          54
# 3                       Fashion & Retail  ==> LVMH  69 years old          55
# 4                         Technology  ==> Facebook          1985          56
#
#   gender        country                                              image  \
# 0   None  United States  https://specials-images.forbesimg.com/imageser...
# 1      M           None  https://specials-images.forbesimg.com/imageser...
# ...

# %%
# Dropping old Name columns 
final_df.drop(columns =["Last Name"], inplace = True)

# %%
cols_name = list(final_df.columns.values)
print(cols_name)
# Out:
# ['id', 'lastName', 'position', 'worth', 'Source', 'age', 'Unnamed: 0', 'gender', 'country', 'image', 'First Name']

# %%
cols_name = ['id', 'First Name', 'lastName', 'position', 'worth', 'Source', 'age', 'Unnamed: 0', 'gender', 'country', 'image']

final_df = final_df.reindex(columns=cols_name)
final_df.head()
# Out:
#      id First Name    lastName  position       worth  \
# 0  5227       Jeff       Bezos       1.0  112.0 BUSD
# 1  2642       Bill       Gates       2.0   90.0 BUSD
# 2  5422     Warren     Buffett       3.0   84.0 BUSD
# 3  8183    Bernard     Arnault       4.0   72.0 BUSD
# 4  5642       Mark  Zuckerberg       5.0   71.0 BUSD
#
#                                             Source           age  Unnamed: 0  \
# 0                           Technology  ==> Amazon  54 years old          52
# 1                        Technology  ==> Microsoft  62 years old          53
# 2  Finance and Investments  ==> Berkshire Hathaway  87 years old          54
# 3                       Fashion & Retail  ==> LVMH  69 years old          55
# 4                         Technology  ==> Facebook          1985          56
#
#   gender        country                                              image
# 0   None  United States  https://specials-images.forbesimg.com/imageser...
# ...

# %%
final_df.columns
# Out:
# Index(['id', 'First Name', 'lastName', 'position', 'worth', 'Source', 'age',
#        'Unnamed: 0', 'gender', 'country', 'image'],
#       dtype='object')

# %%
columns = ['ID', 'First Name', 'Last Name', 'Position', 'Worth', 'Source', 'Age',
       'Unnamed: 0', 'Gender', 'Country', 'Image']

# %%
final_df.columns = columns

# %%
final_df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
final_df.head()
# Out:
#      ID First Name   Last Name  Position       Worth  \
# 0  5227       Jeff       Bezos       1.0  112.0 BUSD
# 1  2642       Bill       Gates       2.0   90.0 BUSD
# 2  5422     Warren     Buffett       3.0   84.0 BUSD
# 3  8183    Bernard     Arnault       4.0   72.0 BUSD
# 4  5642       Mark  Zuckerberg       5.0   71.0 BUSD
#
#                                             Source           Age   Gender  \
# 0                           Technology  ==> Amazon  54 years old  b'None'
# 1                        Technology  ==> Microsoft  62 years old     b'M'
# 2  Finance and Investments  ==> Berkshire Hathaway  87 years old     b'M'
# 3                       Fashion & Retail  ==> LVMH  69 years old     b'M'
# 4                         Technology  ==> Facebook          1985     b'M'
#
#          Country                                              Image
# 0  United States  https://specials-images.forbesimg.com/imageser...
# ...

# %%
# final_df.dtypes

# %%
final_df.index.values
# Out:
# array([   0,    1,    2, ..., 2205, 2206, 2207])

# %%
null_cols = final_df.isnull().sum()

# %%
null_cols
null_cols[null_cols > 0]
# Out:
# Age       65
# Gender    13
# dtype: int64

# %% [markdown]
# # GENDER NULES

# %%
final_df = pd.read_csv('forbes.csv')

# %%
final_df.head()
# Out:
#      ID First Name   Last Name  Position       Worth  \
# 0  5227       Jeff       Bezos       1.0  112.0 BUSD
# 1  2642       Bill       Gates       2.0   90.0 BUSD
# 2  5422     Warren     Buffett       3.0   84.0 BUSD
# 3  8183    Bernard     Arnault       4.0   72.0 BUSD
# 4  5642       Mark  Zuckerberg       5.0   71.0 BUSD
#
#                                             Source           Age  Unnamed: 0  \
# 0                           Technology  ==> Amazon  54 years old          52
# 1                        Technology  ==> Microsoft  62 years old          53
# 2  Finance and Investments  ==> Berkshire Hathaway  87 years old          54
# 3                       Fashion & Retail  ==> LVMH  69 years old          55
# 4                         Technology  ==> Facebook          1985          56
#
#   Gender        Country                                              Image
# 0   None  United States  https://specials-images.forbesimg.com/imageser...
# ...

# %%
final_df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
final_df.Gender.unique()
# Out:
# array(['None', 'M', 'Male', 'F', nan, 'Female'], dtype=object)

# %%
null_cols = final_df.isnull().sum()
null_cols
null_cols[null_cols > 0]
# Out:
# Age       65
# Gender    13
# dtype: int64

# %%
null_displ = final_df[(final_df['Gender'].isnull()==True)]

# %%
null_displ = null_displ[['ID', 'First Name', 'Last Name', 'Position', 'Worth', 'Source', 'Age', 'Gender', 'Country', 'Image']]
null_displ
# Out:
#         ID First Name      Last Name  Position      Worth  \
# 26    1202      Beate   Albrecht jr.      27.0  29.8 BUSD
# 163   7836  Gianluigi         Aponte     164.0   9.3 BUSD
# 224   1197      Willi       Liebherr     225.0   7.1 BUSD
# 309   5024        Tom           Love     310.0   5.8 BUSD
# 426   3416     Philip          Green     427.0   4.8 BUSD
# 529   3488       Jack     Dangermond     530.0   4.1 BUSD
# 581   9068    Stewart        Resnick     582.0   3.9 BUSD
# 596   7398   Dominika        Kulczyk     597.0   3.8 BUSD
# 731   6616     Andrew         Cherng     732.0   3.2 BUSD
# 766   8071         Do          Chang     767.0   3.1 BUSD
# 1197  7859        Ong  Ong beng seng    1198.0   2.1 BUSD
# 1260  9780    Chuchat      Petaumpai    1261.0   2.0 BUSD
# 1290  4362  Jean-paul         Clozel    1291.0   1.9 BUSD
#
#                                              Source           Age Gender  \
# 26               Fashion & Retail  ==> supermarkets  66 years old   None
# ...

# %%
final_df.Gender.unique()
# Out:
# array(['None', 'M', 'Male', 'F', nan, 'Female'], dtype=object)

# %%
display(final_df.loc[26, 'Gender'])
# Out:
# nan

# %%
final_df.loc[26, 'Gender']
# Out:
# nan

# %% [markdown]
# # GENDER Manualy changing values

# %%
# Out:
#      ID First Name   Last Name  Position       Worth  \
# 0  5227       Jeff       Bezos       1.0  112.0 BUSD
# 1  2642       Bill       Gates       2.0   90.0 BUSD
# 2  5422     Warren     Buffett       3.0   84.0 BUSD
# 3  8183    Bernard     Arnault       4.0   72.0 BUSD
# 4  5642       Mark  Zuckerberg       5.0   71.0 BUSD
#
#                                             Source           Age   Gender  \
# 0                           Technology  ==> Amazon  54 years old  b'None'
# 1                        Technology  ==> Microsoft  62 years old     b'M'
# 2  Finance and Investments  ==> Berkshire Hathaway  87 years old     b'M'
# 3                       Fashion & Retail  ==> LVMH  69 years old     b'M'
# 4                         Technology  ==> Facebook          1985     b'M'
#
#          Country                                              Image
# 0  United States  https://specials-images.forbesimg.com/imageser...
# ...

# %% [markdown]
# # POSITION to INT

# %%
final_df.astype({"Position": int})
# Out:
#         ID First Name   Last Name  Position       Worth  \
# 0     5227       Jeff       Bezos         1  112.0 BUSD
# 1     2642       Bill       Gates         2   90.0 BUSD
# 2     5422     Warren     Buffett         3   84.0 BUSD
# 3     8183    Bernard     Arnault         4   72.0 BUSD
# 4     5642       Mark  Zuckerberg         5   71.0 BUSD
# ...    ...        ...         ...       ...         ...
# 2203  7670       Zhao        Zhao      2204    1.0 BUSD
# 2204  1310       Zhou        Zhou      2205    1.0 BUSD
# 2205  4488        Zhu         Zhu      2206    1.0 BUSD
# 2206  7152       Zhuo        Zhuo      2207    1.0 BUSD
# 2207  7214      Olgun       Zorlu      2208    1.0 BUSD
#
#                                                Source           Age  Gender  \
# 0                              Technology  ==> Amazon  54 years old    None
# 1                           Technology  ==> Microsoft  62 years old       M
# ...

# %%
final_df.Position.dtype
# Out:
# dtype('float64')

# %%
final_df.astype({'Position': int}).dtypes
# Out:
# ID             int64
# First Name    object
# Last Name     object
# Position       int64
# Worth         object
# Source        object
# Age           object
# Gender        object
# Country       object
# Image         object
# dtype: object

# %%
final_df.Position.unique()
# Out:
# array([1.000e+00, 2.000e+00, 3.000e+00, ..., 2.206e+03, 2.207e+03,
#        2.208e+03])

# %% [markdown]
# # AGE to INT

# %%
final_df.Age.dtype
# Out:
# dtype('O')

# %%
final_df.Age.unique()
# Out:
# array(['54 years old', '62 years old', '87 years old', '69 years old',
#        '1985', '82 years old', '78 years old', '73 years old',
#        '76 years old', '45 years old', '44 years old', '70 years old',
#        '68 years old', '46 years old', '64 years old', '61 years old',
#        '53 years old', '84 years old', '90 years old', '59 years old',
#        '63 years old', '66 years old', '80 years old', '81 years old',
#        '56 years old', '79 years old', '74 years old', '60 years old',
#        '93 years old', '52 years old', '1983', '65 years old',
#        '83 years old', '67 years old', '75 years old', '89 years old',
#        None, '72 years old', '48 years old', '77 years old',
#        '86 years old', '57 years old', '1988', '55 years old',
#        '94 years old', '47 years old', '71 years old', '92 years old',
#        '88 years old', '85 years old', '49 years old', '51 years old',
#        '50 years old', '43 years old', '42 years old', '91 years old',
# ...

# %%
final_df.shape
# Out:
# (2208, 10)

# %%
final_df.duplicated().sum()
# Out:
# 0

# %%
final_df.Worth.duplicated().sum()
# Out:
# 2016
