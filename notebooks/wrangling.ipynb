# %%
import pandas as pd
import numpy as np
import pymysql

# %%
raw_df = pd.read_csv('../data/raw_df.csv')

# %%
raw_df
# Out:
#         id    lastName           age  Unnamed: 0_x  gender        country  \
# 0     5227       bEZOS  54 years old            52    None  United States
# 1     2642       GATES  62 years old            53       M           None
# 2     5422     bufFETT  87 years old            54       M           None
# 3     8183     aRNAULt  69 years old            55       M         France
# 4     5642  zuckeRBERG          1985            56       M            USA
# ...    ...         ...           ...           ...     ...            ...
# 2203  7670        zhAO  51 years old          2255    None          China
# 2204  1310        zhOU  55 years old          2256       M          China
# 2205  4488         zHU  51 years old          2257       M           None
# 2206  7152        zhUO  52 years old          2258  Female      Hong Kong
# 2207  7214       zORLU  54 years old          2259    None         Turkey
#
#                                                   image  Unnamed: 0_y  \
# 0     https://specials-images.forbesimg.com/imageser...            52
# 1     https://specials-images.forbesimg.com/imageser...            53
# 2     https://specials-images.forbesimg.com/imageser...            54
# 3     https://specials-images.forbesimg.com/imageser...            55
# 4     https://specials-images.forbesimg.com/imageser...            56
# ...                                                 ...           ...
# 2203  https://specials-images.forbesimg.com/imageser...          2255
# 2204  https://specials-images.forbesimg.com/imageser...          2256
# 2205  https://specials-images.forbesimg.com/imageser...          2257
# 2206  https://specials-images.forbesimg.com/imageser...          2258
# 2207  https://specials-images.forbesimg.com/imageser...          2259
#
#                                                Source       worth  \
# 0                              Technology  ==> Amazon  112.0 BUSD
# 1                           Technology  ==> Microsoft   90.0 BUSD
# 2     Finance and Investments  ==> Berkshire Hathaway   84.0 BUSD
# 3                          Fashion & Retail  ==> LVMH   72.0 BUSD
# 4                            Technology  ==> Facebook   71.0 BUSD
# ...                                               ...         ...
# 2203     Fashion & Retail  ==> fashion, entertainment    1.0 BUSD
# 2204          Manufacturing  ==> electrical equipment    1.0 BUSD
# 2205          Manufacturing  ==> electrical equipment    1.0 BUSD
# 2206        Manufacturing  ==> printed circuit boards    1.0 BUSD
# 2207                     Diversified  ==> diversified    1.0 BUSD
#
#               worthChange  realTimeWorth  realTimePosition             name  \
# 0        0.0 millions USD            NaN                 1       jeff BEZos
# 1     -0.001 millions USD            NaN                 2       bill GATES
# 2     -0.002 millions USD            NaN                 3   warrEN BUFFEtt
# 3        0.0 millions USD            NaN                 4  bernarD ARNAULT
# 4        0.0 millions USD            NaN                 5  mark zUCKERBerg
# ...                   ...            ...               ...              ...
# 2203     0.0 millions USD            NaN              2134   zHAO XIAOQIANG
# 2204     nan millions USD            NaN              2134  zhOU LIANGZHang
# 2205     0.0 millions USD            NaN              1856     zhu XINGMING
# 2206     0.0 millions USD            NaN              1978         ZHUO JUn
# 2207     nan millions USD            NaN              1978      OLGUN ZORlu
#
#       position  Unnamed: 0
# 0          1.0          52
# 1          2.0          53
# 2          3.0          54
# 3          4.0          55
# 4          5.0          56
# ...        ...         ...
# 2203    2204.0        2255
# 2204    2205.0        2256
# 2205    2206.0        2257
# 2206    2207.0        2258
# 2207    2208.0        2259
#
# [2208 rows x 16 columns]

# %%
col_todrop = [ 'worthChange', 'Unnamed: 0_x', 'Unnamed: 0_y', 'realTimeWorth', 'realTimePosition', 'Unnamed: 0', 'image']

# %% [markdown]
# # DROP COL

# %%
def drop(df, list_col_todrop):
    drop
    df.drop(list_col_todrop, axis=1, inplace=True)
    cols = list(df.columns.values)
    cols = ['id', 'name', 'position', 'Source', 'worth', 'lastName', 'age', 'gender', 'country']
    df = df.reindex(columns=cols)
    return df

# %%
final_df=drop(raw_df, col_todrop)

# %%
final_df
# Out:
#         id             name  position  \
# 0     5227       jeff BEZos       1.0
# 1     2642       bill GATES       2.0
# 2     5422   warrEN BUFFEtt       3.0
# 3     8183  bernarD ARNAULT       4.0
# 4     5642  mark zUCKERBerg       5.0
# ...    ...              ...       ...
# 2203  7670   zHAO XIAOQIANG    2204.0
# 2204  1310  zhOU LIANGZHang    2205.0
# 2205  4488     zhu XINGMING    2206.0
# 2206  7152         ZHUO JUn    2207.0
# 2207  7214      OLGUN ZORlu    2208.0
#
#                                                Source       worth    lastName  \
# 0                              Technology  ==> Amazon  112.0 BUSD       bEZOS
# 1                           Technology  ==> Microsoft   90.0 BUSD       GATES
# 2     Finance and Investments  ==> Berkshire Hathaway   84.0 BUSD     bufFETT
# 3                          Fashion & Retail  ==> LVMH   72.0 BUSD     aRNAULt
# 4                            Technology  ==> Facebook   71.0 BUSD  zuckeRBERG
# ...                                               ...         ...         ...
# 2203     Fashion & Retail  ==> fashion, entertainment    1.0 BUSD        zhAO
# 2204          Manufacturing  ==> electrical equipment    1.0 BUSD        zhOU
# 2205          Manufacturing  ==> electrical equipment    1.0 BUSD         zHU
# 2206        Manufacturing  ==> printed circuit boards    1.0 BUSD        zhUO
# 2207                     Diversified  ==> diversified    1.0 BUSD       zORLU
#
#                age  gender        country
# 0     54 years old    None  United States
# 1     62 years old       M           None
# 2     87 years old       M           None
# 3     69 years old       M         France
# 4             1985       M            USA
# ...            ...     ...            ...
# 2203  51 years old    None          China
# 2204  55 years old       M          China
# 2205  51 years old       M           None
# 2206  52 years old  Female      Hong Kong
# 2207  54 years old    None         Turkey
#
# [2208 rows x 9 columns]

# %% [markdown]
# #  Separate 'name' Column

# %%
def new_name (df):
    col=df["name"].str.split(" ", n = 1, expand = True) 
    df["First Name"]= col[0]
    df["Last Name"]= col[1] 
    return df

# %%
new_name(final_df)
# Out:
#         id             name  position  \
# 0     5227       jeff BEZos       1.0
# 1     2642       bill GATES       2.0
# 2     5422   warrEN BUFFEtt       3.0
# 3     8183  bernarD ARNAULT       4.0
# 4     5642  mark zUCKERBerg       5.0
# ...    ...              ...       ...
# 2203  7670   zHAO XIAOQIANG    2204.0
# 2204  1310  zhOU LIANGZHang    2205.0
# 2205  4488     zhu XINGMING    2206.0
# 2206  7152         ZHUO JUn    2207.0
# 2207  7214      OLGUN ZORlu    2208.0
#
#                                                Source       worth    lastName  \
# 0                              Technology  ==> Amazon  112.0 BUSD       bEZOS
# 1                           Technology  ==> Microsoft   90.0 BUSD       GATES
# 2     Finance and Investments  ==> Berkshire Hathaway   84.0 BUSD     bufFETT
# 3                          Fashion & Retail  ==> LVMH   72.0 BUSD     aRNAULt
# 4                            Technology  ==> Facebook   71.0 BUSD  zuckeRBERG
# ...                                               ...         ...         ...
# 2203     Fashion & Retail  ==> fashion, entertainment    1.0 BUSD        zhAO
# 2204          Manufacturing  ==> electrical equipment    1.0 BUSD        zhOU
# 2205          Manufacturing  ==> electrical equipment    1.0 BUSD         zHU
# 2206        Manufacturing  ==> printed circuit boards    1.0 BUSD        zhUO
# 2207                     Diversified  ==> diversified    1.0 BUSD       zORLU
#
#                age  gender        country First Name   Last Name
# 0     54 years old    None  United States       jeff       BEZos
# 1     62 years old       M           None       bill       GATES
# 2     87 years old       M           None     warrEN     BUFFEtt
# 3     69 years old       M         France    bernarD     ARNAULT
# 4             1985       M            USA       mark  zUCKERBerg
# ...            ...     ...            ...        ...         ...
# 2203  51 years old    None          China       zHAO   XIAOQIANG
# 2204  55 years old       M          China       zhOU  LIANGZHang
# 2205  51 years old       M           None        zhu    XINGMING
# 2206  52 years old  Female      Hong Kong       ZHUO         JUn
# 2207  54 years old    None         Turkey      OLGUN       ZORlu
#
# [2208 rows x 11 columns]

# %%
def format_data(df): 

    for i in range(df.shape[0]): 
        df.iat[i, 1]= df.iat[i, 1].strip().capitalize() 
        df.iat[i, 5]= df.iat[i, 5].strip().capitalize()
        df.iat[i, 9]= df.iat[i, 9].strip().capitalize() 
  

format_data(final_df) 
final_df.head()
# Out:
#      id             name  position  \
# 0  5227       Jeff bezos       1.0
# 1  2642       Bill gates       2.0
# 2  5422   Warren buffett       3.0
# 3  8183  Bernard arnault       4.0
# 4  5642  Mark zuckerberg       5.0
#
#                                             Source       worth    lastName  \
# 0                           Technology  ==> Amazon  112.0 BUSD       Bezos
# 1                        Technology  ==> Microsoft   90.0 BUSD       Gates
# 2  Finance and Investments  ==> Berkshire Hathaway   84.0 BUSD     Buffett
# 3                       Fashion & Retail  ==> LVMH   72.0 BUSD     Arnault
# 4                         Technology  ==> Facebook   71.0 BUSD  Zuckerberg
#
#             age gender        country First Name   Last Name
# 0  54 years old   None  United States       Jeff       BEZos
# 1  62 years old      M           None       Bill       GATES
# 2  87 years old      M           None     Warren     BUFFEtt
# 3  69 years old      M         France    Bernard     ARNAULT
# 4          1985      M            USA       Mark  zUCKERBerg

# %%
name_drop = ['name', 'Last Name', 'id' ]

# %%
final_df = drop(final_df, name_drop)

# %% [markdown]
# # Re-indexing Cols

# %%
reindex_col = ['position', 'worth', 'First Name', 'lastName', 'age', 'gender', 'Source', 'country']
