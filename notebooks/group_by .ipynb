# %%
import pandas as pd 
# !pip install sqlalchemy

# %%
final_df = pd.read_csv("../data/finished_df.csv")
final_df.head()
# Out:
#    Position First Name   Last Name  Age       Worth     Gender_cat  \
# 0         1       Jeff       Bezos   54  112.0 BUSD  Not Available
# 1         2       Bill       Gates   62   90.0 BUSD           Male
# 2         3     Warren     Buffett   87   84.0 BUSD           Male
# 3         4    Bernard     Arnault   69   72.0 BUSD           Male
# 4         5       Mark  Zuckerberg   33   71.0 BUSD           Male
#
#                                             Source        Country  \
# 0                           Technology  ==> Amazon  United States
# 1                        Technology  ==> Microsoft  United States
# 2  Finance and Investments  ==> Berkshire Hathaway  United States
# 3                       Fashion & Retail  ==> LVMH         France
# 4                         Technology  ==> Facebook            USA
#
#                                                Image
# 0  https://specials-images.forbesimg.com/imageser...
# 1  https://specials-images.forbesimg.com/imageser...
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2208 entries, 0 to 2207
# Data columns (total 9 columns):
# Position      2208 non-null int64
# First Name    2208 non-null object
# Last Name     2208 non-null object
# Age           2208 non-null int64
# Worth         2208 non-null object
# Gender_cat    2208 non-null object
# Source        2208 non-null object
# Country       2208 non-null object
# Image         2208 non-null object
# dtypes: int64(2), object(7)
# memory usage: 155.4+ KB

# %%
tertiary_ed = pd.read_csv('../data/tertiary_ed.csv')
tertiary_ed.head()
# Out:
#      Country  Age25–64(%)
# 0  Australia           42
# 1    Austria           30
# 2    Belgium           37
# 3     Brazil           14
# 4     Canada           54

# %%
final_grouped = final_df.groupby('Country')
final_grouped.head()
# Out:
#       Position First Name               Last Name  Age       Worth  \
# 0            1       Jeff                   Bezos   54  112.0 BUSD
# 1            2       Bill                   Gates   62   90.0 BUSD
# 2            3     Warren                 Buffett   87   84.0 BUSD
# 3            4    Bernard                 Arnault   69   72.0 BUSD
# 4            5       Mark              Zuckerberg   33   71.0 BUSD
# ...        ...        ...                     ...  ...         ...
# 1972      1973        Ion                  Tiriac   79    1.2 BUSD
# 2022      2023    Gustavo                Cisneros   73    1.1 BUSD
# 2023      2024     Sandor                  Csanyi   65    1.1 BUSD
# 2109      2110     Vardis  Vardinoyannis & family   85    1.1 BUSD
# 2115      2116      Myron                   Wentz   78    1.1 BUSD
#
#          Gender_cat                                           Source  \
# 0     Not Available                           Technology  ==> Amazon
# ...

# %%
final_df.describe()
# Out:
#           Position          Age
# count  2208.000000  2208.000000
# mean   1104.500000    61.914402
# std     637.539018    16.860213
# min       1.000000     0.000000
# 25%     552.750000    53.000000
# 50%    1104.500000    63.000000
# 75%    1656.250000    73.000000
# max    2208.000000    99.000000

# %%
final_grouped.describe()
# Out:
#                Position                                                     \
#                   count         mean          std     min      25%     50%
# Country
# Algeria             1.0   563.000000          NaN   563.0   563.00   563.0
# Angola              1.0   933.000000          NaN   933.0   933.00   933.0
# Argentina           9.0  1523.444444   465.599912   796.0  1373.00  1503.0
# Australia          43.0  1306.860465   622.345165    71.0   737.00  1423.0
# Austria             8.0  1047.375000   725.715989    38.0   563.25  1049.5
# ...                 ...          ...          ...     ...      ...     ...
# United Kingdom     46.0   968.369565   615.462405    55.0   388.50   990.5
# United States     518.0   946.575290   594.500952     1.0   464.75   870.5
# Venezuela           2.0  1252.500000  1089.651550   482.0   867.25  1252.5
# Vietnam             4.0  1131.250000   599.349300   512.0   715.25  1084.5
# ...

# %%
merged_ter = pd.merge(final_df, tertiary_ed, on='Country', how='outer')
merged_ter.head()
# Out:
#    Position First Name Last Name   Age       Worth     Gender_cat  \
# 0       1.0       Jeff     Bezos  54.0  112.0 BUSD  Not Available
# 1       2.0       Bill     Gates  62.0   90.0 BUSD           Male
# 2       3.0     Warren   Buffett  87.0   84.0 BUSD           Male
# 3       8.0    Charles      Koch  82.0   60.0 BUSD           Male
# 4      10.0      Larry   Ellison  73.0   58.5 BUSD           Male
#
#                                             Source        Country  \
# 0                           Technology  ==> Amazon  United States
# 1                        Technology  ==> Microsoft  United States
# 2  Finance and Investments  ==> Berkshire Hathaway  United States
# 3                 Diversified  ==> Koch Industries  United States
# 4                         Technology  ==> software  United States
#
#                                                Image  Age25–64(%)
# 0  https://specials-images.forbesimg.com/imageser...         44.0
# ...

# %%
merged_ter.tail(10)
# Out:
#       Position First Name Last Name   Age     Worth Gender_cat  \
# 2205    1766.0       Ivan   Chrenko  50.0  1.3 BUSD       Male
# 2206    1973.0        Ion    Tiriac  79.0  1.2 BUSD       Male
# 2207    2024.0     Sandor    Csanyi  65.0  1.1 BUSD       Male
# 2208       NaN        NaN       NaN   NaN       NaN        NaN
# 2209       NaN        NaN       NaN   NaN       NaN        NaN
# 2210       NaN        NaN       NaN   NaN       NaN        NaN
# 2211       NaN        NaN       NaN   NaN       NaN        NaN
# 2212       NaN        NaN       NaN   NaN       NaN        NaN
# 2213       NaN        NaN       NaN   NaN       NaN        NaN
# 2214       NaN        NaN       NaN   NaN       NaN        NaN
#
#                                                Source       Country  \
# 2205                     Real Estate  ==> real estate      Slovakia
# 2206  Finance and Investments  ==> banking, insurance       Romania
# ...

# %%
merged_ter.drop(merged_ter.index[[2208, 2209, 2210, 2211, 2212, 2213, 2214]])
# Out:
#       Position First Name Last Name   Age       Worth     Gender_cat  \
# 0          1.0       Jeff     Bezos  54.0  112.0 BUSD  Not Available
# 1          2.0       Bill     Gates  62.0   90.0 BUSD           Male
# 2          3.0     Warren   Buffett  87.0   84.0 BUSD           Male
# 3          8.0    Charles      Koch  82.0   60.0 BUSD           Male
# 4         10.0      Larry   Ellison  73.0   58.5 BUSD           Male
# ...        ...        ...       ...   ...         ...            ...
# 2203    1690.0        Hoi       Hoi  65.0    1.4 BUSD           Male
# 2204    1710.0     Strive  Masiyiwa  57.0    1.4 BUSD  Not Available
# 2205    1766.0       Ivan   Chrenko  50.0    1.3 BUSD           Male
# 2206    1973.0        Ion    Tiriac  79.0    1.2 BUSD           Male
# 2207    2024.0     Sandor    Csanyi  65.0    1.1 BUSD           Male
#
#                                                Source        Country  \
# ...

# %%
#merged_ter = merged_ter.to_csv('../data/merged_ter.csv', index=False)

# %%
billpc_tered_df =merged_ter.groupby(['Country', 'Age25–64(%)']).size().reset_index(name= 'Billionaires per Country')

# %%
billpc_tered_df
# Out:
#            Country  Age25–64(%)  Billionaires per Country
# 0        Australia         42.0                        43
# 1          Austria         30.0                         8
# 2          Belgium         37.0                         2
# 3           Brazil         14.0                        42
# 4           Canada         54.0                        46
# 5            Chile         21.0                        11
# 6            China         17.0                       373
# 7         Colombia         22.0                         3
# 8       Costa Rica         18.0                         1
# 9   Czech Republic         22.0                         6
# 10         Denmark         36.0                        10
# 11         Estonia         38.0                         1
# 12         Finland         42.0                         6
# 13          France         32.0                        40
# 14         Germany         27.0                       123
# ...

# %%
# Out:
# <bound method Series.sum of 0      43
# 1       8
# 2       2
# 3      42
# 4      46
# 5      11
# 6     373
# 7       3
# 8       1
# 9       6
# 10     10
# 11      1
# 12      6
# 13     40
# 14    123
# 15      4
# 16      1
# 17      1
# 18     20
# 19      9
# 20     20
# 21     43
# 22     35
# 23      1
# 24      1
# 25      1
# 26     16
# 27      9
# 28      2
# 29     15
# 30      6
# 31      1
# 32    101
# 33      1
# 34      1
# 35      1
# 36      5
# 37     44
# 38     29
# 39     32
# 40     36
# 41     36
# 42     46
# 43    518
# Name: Billionaires per Country, dtype: int64>
