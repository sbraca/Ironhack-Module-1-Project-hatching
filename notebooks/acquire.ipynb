# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine
import pymysql
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:////Users/Stefania/downloads/stefaniabraca.db')
query = "select * from personal_info"
dfpersonal_info = pd.read_sql_query(query, engine)
query = "select * from business_info"
dfbusiness_info = pd.read_sql_query(query, engine)
query = "select * from rank_info"
dfrank_info = pd.read_sql_query(query, engine)

# %%
def get_main_data(df1, df2, df3):

    merged_df = df1.merge(df2, on='id')
    raw_df = merged_df.merge(df3, on='id')
    return raw_df

raw_df = get_main_data(dfpersonal_info, dfbusiness_info, dfrank_info)

# %%
raw_df
# Out:
#         id    lastName           age  Unnamed: 0_x  gender        country  \
# 0     5227       bEZOS  54 years old            52    None  United States
# 1     2642       GATES  62 years old            53       M           None
# 2     5422     bufFETT  87 years old            54       M           None
# 3     8183     aRNAULt  69 years old            55       M         France
# 4     5642  zuckeRBERG          1985            56       M            USA
# ...    ...         ...           ...           ...     ...            ...
# 2203  7670        zhAO  51 years old          2255    None          China
# 2204  1310        zhOU  55 years old          2256       M          China
# 2205  4488         zHU  51 years old          2257       M           None
# 2206  7152        zhUO  52 years old          2258  Female      Hong Kong
# 2207  7214       zORLU  54 years old          2259    None         Turkey
#
#                                                   image  Unnamed: 0_y  \
# 0     https://specials-images.forbesimg.com/imageser...            52
# 1     https://specials-images.forbesimg.com/imageser...            53
# 2     https://specials-images.forbesimg.com/imageser...            54
# 3     https://specials-images.forbesimg.com/imageser...            55
# 4     https://specials-images.forbesimg.com/imageser...            56
# ...                                                 ...           ...
# 2203  https://specials-images.forbesimg.com/imageser...          2255
# 2204  https://specials-images.forbesimg.com/imageser...          2256
# 2205  https://specials-images.forbesimg.com/imageser...          2257
# 2206  https://specials-images.forbesimg.com/imageser...          2258
# 2207  https://specials-images.forbesimg.com/imageser...          2259
#
#                                                Source       worth  \
# 0                              Technology  ==> Amazon  112.0 BUSD
# 1                           Technology  ==> Microsoft   90.0 BUSD
# 2     Finance and Investments  ==> Berkshire Hathaway   84.0 BUSD
# 3                          Fashion & Retail  ==> LVMH   72.0 BUSD
# 4                            Technology  ==> Facebook   71.0 BUSD
# ...                                               ...         ...
# 2203     Fashion & Retail  ==> fashion, entertainment    1.0 BUSD
# 2204          Manufacturing  ==> electrical equipment    1.0 BUSD
# 2205          Manufacturing  ==> electrical equipment    1.0 BUSD
# 2206        Manufacturing  ==> printed circuit boards    1.0 BUSD
# 2207                     Diversified  ==> diversified    1.0 BUSD
#
#               worthChange realTimeWorth  realTimePosition             name  \
# 0        0.0 millions USD          None                 1       jeff BEZos
# 1     -0.001 millions USD          None                 2       bill GATES
# 2     -0.002 millions USD          None                 3   warrEN BUFFEtt
# 3        0.0 millions USD          None                 4  bernarD ARNAULT
# 4        0.0 millions USD          None                 5  mark zUCKERBerg
# ...                   ...           ...               ...              ...
# 2203     0.0 millions USD          None              2134   zHAO XIAOQIANG
# 2204     nan millions USD          None              2134  zhOU LIANGZHang
# 2205     0.0 millions USD          None              1856     zhu XINGMING
# 2206     0.0 millions USD          None              1978         ZHUO JUn
# 2207     nan millions USD          None              1978      OLGUN ZORlu
#
#       position  Unnamed: 0
# 0          1.0          52
# 1          2.0          53
# 2          3.0          54
# 3          4.0          55
# 4          5.0          56
# ...        ...         ...
# 2203    2204.0        2255
# 2204    2205.0        2256
# 2205    2206.0        2257
# 2206    2207.0        2258
# 2207    2208.0        2259
#
# [2208 rows x 16 columns]

# %%
raw_df.to_csv('../data/raw_df.csv', index=False)
